# %% [markdown]
# # TensorRT Quantization Tutorial
#
# This notebook is designed to show the features of the TensorRT passes integrated into MASE as part of the MASERT framework. The following demonstrations were run on a NVIDIA RTX A2000 GPU with a Intel(R) Xeon(R) CPU E5-2690 v4 @ 2.60GHz CPU.
#
# ## Section 1. INT8 Quantization
# Firstly, we will show you how to do a int8 quantization of a simple model, `jsc-toy`, and compare the quantized model to the original model using the `Machop API`. The quantization process is split into the following stages, each using their own individual pass, and are explained in depth at each subsection:
#
# 1. [Fake quantization](#section-11-fake-quantization): `tensorrt_fake_quantize_transform_pass`
# 2. [Calibration](#section-12-calibration): `tensorrt_calibrate_transform_pass`
# 3. [Quantized Aware Training](#section-13-quantized-aware-training-qat): `tensorrt_fine_tune_transform_pass`
# 4. [Quantization](#section-14-tensorrt-quantization): `tensorrt_engine_interface_pass`
# 5. [Analysis](#section-15-performance-analysis): `tensorrt_analysis_pass`
#
# We start by loading in the required libraries and passes required for the notebook as well as ensuring the correct path is set for machop to be used.

# %%
import sys
import os
from pathlib import Path
import toml

# Figure out the correct path
machop_path = Path(".").resolve().parent.parent.parent /"src"
assert machop_path.exists(), "Failed to find machop at: {}".format(machop_path)
sys.path.append(str(machop_path))

# Add directory to the PATH so that chop can be called
new_path = "../../../machop"
full_path = os.path.abspath(new_path)
os.environ['PATH'] += os.pathsep + full_path

from chop.tools.utils import to_numpy_if_tensor
from chop.tools.logger import set_logging_verbosity
from chop.tools import get_cf_args, get_dummy_input
from chop.passes.graph.utils import deepcopy_mase_graph
from chop.tools.get_input import InputGenerator
from chop.tools.checkpoint_load import load_model
from chop.ir import MaseGraph
from chop.models import get_model_info, get_model, get_tokenizer
from chop.dataset import MaseDataModule, get_dataset_info
from chop.passes.graph.transforms import metadata_value_type_cast_transform_pass
from chop.passes.graph import (
    summarize_quantization_analysis_pass,
    add_common_metadata_analysis_pass,
    init_metadata_analysis_pass,
    add_software_metadata_analysis_pass,
    tensorrt_calibrate_transform_pass,
    tensorrt_fake_quantize_transform_pass,
    tensorrt_fine_tune_transform_pass,
    tensorrt_engine_interface_pass,
    runtime_analysis_pass,
    )

set_logging_verbosity("info")
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO     Set logging level to info

# %% [markdown]
# Check dependency (the dependent package "cuda" refers to "cuda-python")

# %%
from chop.tools.check_dependency import check_deps_tensorRT_pass
check_deps_tensorRT_pass(silent=False)
# Out:
# INFO     Extension: All dependencies for TensorRT pass are available.
# True

# %% [markdown]
# Next, we load in the toml file used for quantization. To view the configuration, click [here](../../../machop/configs/tensorrt/jsc_toy_INT8_quantization_by_type.toml).

# %%
import toml
# Path to your TOML file
# JSC_TOML_PATH = 'toy_INT8_quantization_by_type.toml'
JSC_TOML_PATH = 'resnet18_INT8_quant.toml'

# Reading TOML file and converting it into a Python dictionary
with open(JSC_TOML_PATH, 'r') as toml_file:
    pass_args = toml.load(toml_file)

# Extract the 'passes.tensorrt' section and its children
tensorrt_config = pass_args.get('passes', {}).get('tensorrt', {})
print(tensorrt_config)
# Extract the 'passes.runtime_analysis' section and its children
runtime_analysis_config = pass_args.get('passes', {}).get('tensorrt', {}).get('runtime_analysis', {})
print(runtime_analysis_config)
# Out:
# {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile', 'mse', 'entropy'], 'percentiles': [99.0, 99.9, 99.99], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': True}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}
# {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}

# %% [markdown]
# We then create a `MaseGraph` by loading in a model and training it using the toml configuration model arguments.

# %%
from chop.dataset import MaseDataModule
from chop.models import get_model_info
from chop.models import get_model
from chop.tools.get_input import InputGenerator

# Load the basics in
model_name = pass_args['model']
dataset_name = pass_args['dataset']
max_epochs = pass_args['max_epochs']
batch_size = pass_args['batch_size']
learning_rate = pass_args['learning_rate']
accelerator = pass_args['accelerator']

data_module = MaseDataModule(
    name=dataset_name,
    batch_size=batch_size,
    model_name=model_name,
    num_workers=0,
)
data_module.prepare_data()
data_module.setup()

# Add the data_module and other necessary information to the configs
configs = [tensorrt_config, runtime_analysis_config]
for config in configs:
    config['task'] = pass_args['task']
    config['dataset'] = pass_args['dataset']
    config['batch_size'] = pass_args['batch_size']
    config['model'] = pass_args['model']
    config['data_module'] = data_module
    config['accelerator'] = 'cuda' if pass_args['accelerator'] == 'gpu' else pass_args['accelerator']
    if config['accelerator'] == 'gpu':
        os.environ['CUDA_MODULE_LOADING'] = 'LAZY'

model_info = get_model_info(model_name)
# quant_modules.initialize()
model = get_model(
    model_name,
    # task="cls",
    dataset_info=data_module.dataset_info,
    pretrained=False)


input_generator = InputGenerator(
    data_module=data_module,
    model_info=model_info,
    task="cls",
    which_dataloader="train",
)

# generate the mase graph and initialize node metadata
mg = MaseGraph(model=model)
# Out:
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)

# %% [markdown]
# Then we load in the checkpoint. You will have to adjust this according to where it has been stored in the mase_output directory.

# %%
# Load in the trained checkpoint - change this accordingly
JSC_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"


model = load_model(load_name=JSC_CHECKPOINT_PATH, load_type="pl", model=model)
print("load model done!")

# Initiate metadata
dummy_in = next(iter(input_generator))
print("dummy in done")

_ = model(**dummy_in)
print("_ done")

mg, _ = init_metadata_analysis_pass(mg, None)
print("init_metadata_analysis_pass done")

mg, _ = add_common_metadata_analysis_pass(mg, {"dummy_in": dummy_in})
print("add_common_metadata_analysis_pass done")

mg, _ = add_software_metadata_analysis_pass(mg, None)
print("add_software_metadata_analysis_pass done")

mg, _ = metadata_value_type_cast_transform_pass(mg, pass_args={"fn": to_numpy_if_tensor})
print("metadata_value_type_cast_transform_pass done")

# Before we begin, we will copy the original MaseGraph model to use for comparison during quantization analysis
mg_original = deepcopy_mase_graph(mg)
print("deep copy done")
# Out:
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# load model done!
# dummy in done
# _ done
# init_metadata_analysis_pass done
# add_common_metadata_analysis_pass done
# add_software_metadata_analysis_pass done
# metadata_value_type_cast_transform_pass done
# using safe deepcopy
# deep copy done

# %% [markdown]
# As you can see we have succesfully fake quantized all linear layers inside `jsc-toy`. This means that we will be able to simulate a quantized model in order to calibrate and fine tune it. This fake quantization was done on typewise i.e. for linear layers only. See [Section 4](#section-4-layer-wise-mixed-precision) for how to apply quantization layerwise - i.e. only first and second layers for example.

# %%
mg, _ = tensorrt_fake_quantize_transform_pass(mg, pass_args=tensorrt_config)
# summarize_quantization_analysis_pass(mg_original, mg)
summarize_quantization_analysis_pass(mg, pass_args={"save_dir": "quantize_summary_res18", "original_graph": mg_original})
mg, _ = tensorrt_calibrate_transform_pass(mg, pass_args=tensorrt_config)
mg, _ = tensorrt_fine_tune_transform_pass(mg, pass_args=tensorrt_config)
# Out:
# INFO     Applying fake quantization to PyTorch model...
# op is placeholder
# placeholder not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is max_pool2d
# max_pool2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# INFO     Fake quantization applied to PyTorch model.
# INFO     Quantized graph histogram:
# INFO
# | Original type     | OP                  |   Total |   Changed |   Unchanged |
# |-------------------+---------------------+---------+-----------+-------------|
# | AdaptiveAvgPool2d | adaptive_avg_pool2d |       1 |         0 |           1 |
# | BatchNorm2d       | batch_norm2d        |      20 |         0 |          20 |
# | MaxPool2d         | max_pool2d          |       1 |         0 |           1 |
# | QuantConv2d       | conv2d              |      20 |         0 |          20 |
# | QuantLinear       | linear              |       1 |         0 |           1 |
# | ReLU              | relu                |      17 |         0 |          17 |
# | add               | add                 |       8 |         0 |           8 |
# | flatten           | flatten             |       1 |         0 |           1 |
# | output            | output              |       1 |         0 |           1 |
# | x                 | placeholder         |       1 |         0 |           1 |
# INFO     Starting calibration of the model in PyTorch...
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is adaptive_avg_pool2d
# adaptive_avg_pool2d not in QUANTIZEABLE_OP
# op is flatten
# flatten not in QUANTIZEABLE_OP
# op is linear
# node.op == call_module
# op is output
# output not in QUANTIZEABLE_OP
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Enabling Quantization and Disabling Calibration
# WARNING: Logging before flag parsing goes to stderr.
# W0316 17:01:18.132733 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.133850 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.134714 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.136208 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.137121 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.137879 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.138573 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.140170 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.141077 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.142189 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.143619 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.144650 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.145399 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.146770 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.147578 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.149019 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.150357 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.151788 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.152985 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.154338 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.156596 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.157516 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.158558 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.160082 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.161154 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.162107 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.164014 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.164902 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.166110 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.167388 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.168569 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.169637 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.170863 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.171844 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.172682 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.173788 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.176133 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.177526 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.178366 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.179668 140148613170240 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.180736 140148613170240 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 17:01:18.181622 140148613170240 tensor_quantizer.py:174] Disable MaxCalibrator
# W0316 17:01:18.182570 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W0316 17:01:18.182865 140148613170240 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.5527 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.184813 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1400 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.186303 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1920 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.187849 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2111 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.189579 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1081 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.191330 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1980 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.192960 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.8305 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.194564 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1957 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.196098 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1339 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.198009 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1970 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.199918 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.4592 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.201286 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1583 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.202663 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2617 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.204497 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1586 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.206414 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.4592 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.208228 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3493 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.209522 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5922 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.210942 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.213024 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2721 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.214654 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1517 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.216028 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.5547 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.217221 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1277 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.218997 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.6690 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.220477 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1132 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.221659 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=4.5547 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.223215 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2536 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.224844 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4260 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.226114 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.227694 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.3369 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.228620 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0944 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.230158 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.3155 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.231125 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0710 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.232185 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.0641 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.233765 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0598 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.234813 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.3155 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.235660 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.1907 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.236742 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.9587 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.237705 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.238700 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.8835 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.240296 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:18.241336 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=18.9132 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 17:01:18.242656 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.0...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72847    |
# |      Average Precision       |   0.71713    |
# |        Average Recall        |   0.72103    |
# |       Average F1 Score       |   0.71808    |
# |         Average Loss         |   0.81653    |
# |       Average Latency        |  26.318 ms   |
# |   Average GPU Power Usage    |   13.088 W   |
# | Inference Energy Consumption | 0.095681 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_73/model.json
# INFO     Post calibration analysis complete.
# W0316 17:01:24.496675 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6393 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.498311 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1815 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.500494 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.3233 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.502397 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2904 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.504007 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.1992 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.505755 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2525 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.507328 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.1378 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.509038 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2498 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.510911 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.1391 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.513056 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2537 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.514491 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.9315 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.516463 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.517744 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.2695 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.519402 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.521245 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=7.9315 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.523612 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4401 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.525197 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.2080 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.526762 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2007 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.528781 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3785 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.530788 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1949 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.532544 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.7990 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.534394 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1651 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.535832 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.0873 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.537759 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1593 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.539353 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=6.7990 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.541041 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3283 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.543536 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.6945 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.545942 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1263 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.547868 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.3404 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.549772 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1284 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.552100 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4416 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.554438 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1042 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.555996 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.0109 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.558063 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0840 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.559701 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=8.4416 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.561412 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2463 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.563559 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.8278 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.565924 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0714 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.567344 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.1885 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.569239 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0719 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:24.570787 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=18.9132 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 17:01:24.572114 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.9...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72762    |
# |      Average Precision       |   0.71839    |
# |        Average Recall        |   0.72144    |
# |       Average F1 Score       |   0.71913    |
# |         Average Loss         |   0.80697    |
# |       Average Latency        |  26.922 ms   |
# |   Average GPU Power Usage    |   10.315 W   |
# | Inference Energy Consumption | 0.077139 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_74/model.json
# INFO     Post calibration analysis complete.
# W0316 17:01:30.610634 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=3.0586 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.612538 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.2071 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.614557 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.7172 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.616240 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3663 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.617917 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2826 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.619401 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2896 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.620799 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=9.5206 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.622175 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2951 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.623610 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2032 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.625260 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2948 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.626424 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.3618 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.628627 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2492 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.631085 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2628 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.632933 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2424 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.634602 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=10.3618 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.636210 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.5430 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.638141 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.7417 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.640018 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2315 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.641643 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4194 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.643124 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2258 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.644779 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.9510 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.646287 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1993 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.647786 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.3736 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.649508 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2141 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.651160 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=8.9510 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.652904 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3806 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.654549 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4259 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.656037 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1591 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.657299 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.5934 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.658514 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1755 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.660459 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=11.8408 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.662451 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1403 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.663673 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.7618 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.665572 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1098 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.667479 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=11.8408 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.668921 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2988 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.670744 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.4781 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.674752 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0875 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.677359 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.6719 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.679525 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0867 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:30.681534 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=18.9132 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 17:01:30.682822 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.99...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+------------+
# |      Metric (Per Batch)      |   Value    |
# +------------------------------+------------+
# | Average Validation Accuracy  |  0.72802   |
# |      Average Precision       |  0.71891   |
# |        Average Recall        |  0.72206   |
# |       Average F1 Score       |  0.71959   |
# |         Average Loss         |  0.80894   |
# |       Average Latency        | 30.814 ms  |
# |   Average GPU Power Usage    |  9.4047 W  |
# | Inference Energy Consumption | 0.0805 mWh |
# +------------------------------+------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_75/model.json
# INFO     Post calibration analysis complete.
# ...
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=11.0497 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:45.795469 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0888 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:46.091049 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.6242 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:46.258713 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0879 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:46.260141 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=18.9132 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 17:01:46.261456 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator mse...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72817    |
# |      Average Precision       |   0.71912    |
# |        Average Recall        |   0.72227    |
# |       Average F1 Score       |   0.71979    |
# |         Average Loss         |   0.80964    |
# |       Average Latency        |  23.736 ms   |
# |   Average GPU Power Usage    |   12.611 W   |
# | Inference Energy Consumption | 0.083149 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_76/model.json
# INFO     Post calibration analysis complete.
# W0316 17:01:53.298750 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.1257 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:54.654905 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1926 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:56.490779 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=11.0355 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:57.819704 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3665 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:01:59.930432 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.6829 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:01.270216 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3090 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:03.320387 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=12.5249 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:04.774026 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2953 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:06.279525 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.5032 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:07.634191 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2965 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:10.051613 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=14.5162 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:11.409225 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2664 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:13.239340 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.5434 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:14.596400 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2533 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:17.063119 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=14.5162 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:18.438744 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4531 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:20.093641 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.5127 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:21.477844 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2549 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:22.873636 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.9599 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:24.267004 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:25.617659 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.6276 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:26.991730 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2261 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:29.076075 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.3961 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:30.426933 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2659 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:31.786356 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=10.6276 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:33.100894 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4147 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:35.028092 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.2371 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:36.367843 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1992 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:39.570365 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.0222 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:40.874845 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2278 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:43.550259 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=13.7839 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:44.860633 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1693 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:47.207131 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.2772 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:48.557229 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1449 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:51.299221 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=13.7839 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:52.672505 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3188 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:55.390058 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=11.8032 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:56.827649 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1031 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:02:59.119314 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.6292 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:03:00.520220 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1051 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 17:03:00.522446 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=18.9132 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 17:03:00.523741 140148613170240 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator entropy...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72762    |
# |      Average Precision       |    0.7183    |
# |        Average Recall        |   0.72165    |
# |       Average F1 Score       |   0.71913    |
# |         Average Loss         |   0.81111    |
# |       Average Latency        |    29 ms     |
# |   Average GPU Power Usage    |   9.9933 W   |
# | Inference Energy Consumption | 0.080501 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_77/model.json
# INFO     Post calibration analysis complete.
# INFO     Succeeded in calibrating the model in PyTorch!
# INFO     Starting Fine Tuning for 2 epochs...
# I0316 17:03:07.382124 140148613170240 rank_zero.py:63] GPU available: True (cuda), used: True
# I0316 17:03:07.383385 140148613170240 rank_zero.py:63] TPU available: False, using: 0 TPU cores
# I0316 17:03:07.383774 140148613170240 rank_zero.py:63] HPU available: False, using: 0 HPUs
# I0316 17:03:07.385474 140148613170240 rank_zero.py:63] You are using a CUDA device ('NVIDIA GeForce RTX 4060 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# I0316 17:03:09.930998 140148613170240 cuda.py:61] LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# I0316 17:03:09.940766 140148613170240 model_summary.py:104]
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | GraphModule        | 11.2 M | train
# 1 | loss_fn   | CrossEntropyLoss   | 0      | train
# 2 | acc_train | MulticlassAccuracy | 0      | train
# 3 | loss_val  | MeanMetric         | 0      | train
# 4 | loss_test | MeanMetric         | 0      | train
# ---------------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.727    Total estimated model params size (MB)
# 114       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# I0316 17:05:57.926141 140148613170240 rank_zero.py:63] `Trainer.fit` stopped: `max_epochs=2` reached.
# INFO     Fine Tuning Complete

# %% [markdown]
# ### Section 1.4 TensorRT Quantization
#
# After QAT, we are now ready to convert the model to a tensorRT engine so that it can be run with the superior inference speeds. To do so, we use the `tensorrt_engine_interface_pass` which converts the `MaseGraph`'s model from a Pytorch one to an ONNX format as an intermediate stage of the conversion.
#
# During the conversion process, the `.onnx` and `.trt` files are stored to their respective folders shown in [Section 1.3](#section-13-quantized-aware-training-qat).
#
# This interface pass returns a dictionary containing the `onnx_path` and `trt_engine_path`.

# %%
mg, meta = tensorrt_engine_interface_pass(mg, pass_args=tensorrt_config)
# Out:
# INFO     Starting reference convert for QAT model...
# INFO     Reference model convert done. Now exporting to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_9/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# [03/16/2025-17:06:01] [TRT] [W] Calibrator is not being used. Users must provide dynamic range for all tensors that are not Int32 or Bool.
# [03/16/2025-17:06:01] [TRT] [E] IBuilder::buildSerializedNetwork: Error Code 4: Internal Error (Calibration failure occurred with no scaling factors detected. This could be due to no int8 calibrator or insufficient custom scales for network layers. Please see int8 sample to setup calibration correctly.)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mg, meta = tensorrt_engine_interface_pass(mg, pass_args=tensorrt_config)
#
# File /workspace/ADLS_Proj/src/chop/passes/utils.py:64, in register_mase_pass.<locals>.decorator.<locals>.wrapped_fn(*args, **kwargs)
#      60 if requires_nightly_torch and not _nightly_torch_installed():
#      61     logger.warning(
#      62         f"Pass '{name}' requires a nightly version of PyTorch, but it is not installed.\nThe function may not work as expected."
#      63     )
# ---> 64 return fn(*args, **kwargs)
#
# File /workspace/ADLS_Proj/src/chop/passes/graph/interface/tensorrt/quantize.py:94, in tensorrt_engine_interface_pass(graph, pass_args)
#      53 """
#      54 Converts a PyTorch model within a MaseGraph to a TensorRT engine, optimizing the model for faster inference speeds.
#      55
#    (...)
#      91 The `.onnx` and `.trt` files are stored according to the directory structure outlined in Section 1.3 of the Quantized Aware Training (QAT) documentation, ensuring organized and accessible storage for these critical files.
#      92 """
#      93 quantizer = Quantizer(pass_args)
# ---> 94 trt_engine_path, onnx_path = quantizer.pytorch_to_trt(graph)
#      96 # Link the model with the graph for further operations or evaluations
#      97 graph.model = torch.fx.GraphModule(graph.model, graph.fx_graph)
#
# File /workspace/ADLS_Proj/src/chop/passes/graph/interface/tensorrt/quantize.py:111, in Quantizer.pytorch_to_trt(self, graph)
#     109 # Model is first converted to ONNX format and then to TensorRT
#     110 ONNX_path = self.pytorch_to_ONNX(graph.model)
# --> 111 TRT_path = self.ONNX_to_TRT(ONNX_path)
#     112 self.export_TRT_model_summary(TRT_path)
#     114 return TRT_path, ONNX_path
#
# File /workspace/ADLS_Proj/src/chop/passes/graph/interface/tensorrt/quantize.py:226, in Quantizer.ONNX_to_TRT(self, ONNX_path)
#     224 serialized_engine = builder.build_serialized_network(network, config)
#     225 if serialized_engine is None:
# --> 226     raise Exception(
#     227         "Failed to build serialized network. A builderflag or config parameter may be incorrect or the ONNX model is unsupported."
#     228     )
#     230 trt_path = prepare_save_path(self.config, method="trt", suffix="trt")
#     231 with open(trt_path, "wb") as f:
#
# Exception: Failed to build serialized network. A builderflag or config parameter may be incorrect or the ONNX model is unsupported.

# %%
mg, meta = tensorrt_engine_interface_pass(mg, pass_args=tensorrt_config)
# Out:
# INFO     Starting reference convert for QAT model...
# INFO     Reference model convert done. Now exporting to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_5/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_6/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_7/model.json

# %%
mg, meta = tensorrt_engine_interface_pass(mg, pass_args=tensorrt_config)
# Out:
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_1/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_2/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_3/model.json

# %% [markdown]
# ### Section 1.5 Performance Analysis
#
# To showcase the improved inference speeds and to evaluate accuracy and other performance metrics, the `tensorrt_analysis_pass` can be used.
#
# The tensorRT engine path obtained the previous interface pass is now inputted into the the analysis pass. The same pass can take a MaseGraph as an input, as well as an ONNX graph. For this comparison, we will first run the anaylsis pass on the original unquantized model and then on the int8 quantized model.

# %%
_, _ = runtime_analysis_pass(mg_original, pass_args=runtime_analysis_config)
_, _ = runtime_analysis_pass(meta['trt_engine_path'], pass_args=runtime_analysis_config)
# Out:
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# |    Average Test Accuracy     |   0.73905   |
# |      Average Precision       |   0.74136   |
# |        Average Recall        |   0.74307   |
# |       Average F1 Score       |   0.74105   |
# |         Average Loss         |   0.73818   |
# |       Average Latency        |  46.81 ms   |
# |   Average GPU Power Usage    |  13.424 W   |
# | Inference Energy Consumption | 0.17455 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_72/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/16/2025-16:58:46] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.73933    |
# |      Average Precision       |   0.74141    |
# |        Average Recall        |   0.74327    |
# |       Average F1 Score       |   0.74114    |
# |         Average Loss         |   0.73806    |
# |       Average Latency        |  19.354 ms   |
# |   Average GPU Power Usage    |   13.729 W   |
# | Inference Energy Consumption | 0.073811 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/tensorrt/version_3/model.json

# %% [markdown]
# As shown above, the latency has decreased around 6x with the `jsc-toy` model without compromising accuracy due to the well calibrated amax and quantization-aware fine tuning and additional runtime optimizations from TensorRT. The inference energy consumption has thus also dropped tremendously and this is an excellent demonstration for the need to quantize in industry especially for LLMs in order to reduce energy usage.
#
# ## Section 2. FP16 Quantization
#
# We will now load in a new toml configuration that uses fp16 instead of int8, whilst keeping the other settings the exact same for a fair comparison. This time however, we will use chop from the terminal which runs all the passes showcased in [Section 1](#section-1---int8-quantization).
#
# Since float quantization does not require calibration, nor is it supported by `pytorch-quantization`, the model will not undergo fake quantization; for the time being this unfortunately means QAT is unavailable and only undergoes Post Training Quantization (PTQ).

# %%
JSC_INT8_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_INT8_quant.toml"
JSC_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {JSC_INT8_BY_TYPE_TOML} --load {JSC_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 02:21:21.056977 140494406755392 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile', 'mse', 'entropy'], 'percentiles': [99.0, 99.9, 99.99], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': True}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     Applying fake quantization to PyTorch model...
# op is placeholder
# placeholder not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is max_pool2d
# max_pool2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is adaptive_avg_pool2d
# adaptive_avg_pool2d not in QUANTIZEABLE_OP
# op is flatten
# flatten not in QUANTIZEABLE_OP
# op is linear
# node.op == call_module
# op is output
# output not in QUANTIZEABLE_OP
# INFO     Fake quantization applied to PyTorch model.
# INFO     Quantized graph histogram:
# INFO
# | Original type     | OP                  |   Total |   Changed |   Unchanged |
# |-------------------+---------------------+---------+-----------+-------------|
# | AdaptiveAvgPool2d | adaptive_avg_pool2d |       1 |         0 |           1 |
# | BatchNorm2d       | batch_norm2d        |      20 |         0 |          20 |
# | MaxPool2d         | max_pool2d          |       1 |         0 |           1 |
# | QuantConv2d       | conv2d              |      20 |         0 |          20 |
# | QuantLinear       | linear              |       1 |         0 |           1 |
# | ReLU              | relu                |      17 |         0 |          17 |
# | add               | add                 |       8 |         0 |           8 |
# | flatten           | flatten             |       1 |         0 |           1 |
# | output            | output              |       1 |         0 |           1 |
# | x                 | placeholder         |       1 |         0 |           1 |
# INFO     Starting calibration of the model in PyTorch...
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.087997 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088167 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088266 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088348 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088433 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088517 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088604 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088695 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088779 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088858 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088949 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089029 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089111 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089190 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089273 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089351 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089435 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089513 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089596 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089676 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089760 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089838 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089920 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089999 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090083 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090162 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090245 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090325 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090409 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090490 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090573 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090651 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090734 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090822 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090906 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090986 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091068 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091146 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091232 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091306 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091391 140494406755392 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091465 140494406755392 tensor_quantizer.py:174] Disable MaxCalibrator
# W0315 02:21:32.091680 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W0315 02:21:32.091738 140494406755392 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6224 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.091941 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1400 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092101 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2234 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092239 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2111 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092375 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1065 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092510 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1980 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092655 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.8358 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092797 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1957 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092946 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1359 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093083 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1970 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093218 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.4627 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093343 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1583 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093477 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2610 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093605 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1586 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093736 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.4627 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093876 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3493 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094006 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5872 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094131 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094259 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2720 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094383 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1517 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094517 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.5370 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094642 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1277 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094769 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.6489 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094891 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1132 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095019 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=4.5370 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095145 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2536 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095278 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4016 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095404 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095533 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.3014 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095656 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0944 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095781 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.2608 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095990 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0710 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096137 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5874 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096266 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0598 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096399 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.2608 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096525 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.1907 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096652 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.9013 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096777 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096904 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.0223 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.097026 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.097127 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.6309 calibrator=MaxCalibrator scale=1.0 quant)
# W0315 02:21:32.097379 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.0...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72608    |
# |      Average Precision       |   0.71486    |
# |        Average Recall        |   0.71875    |
# |       Average F1 Score       |   0.71577    |
# |         Average Loss         |   0.81619    |
# |       Average Latency        |  29.604 ms   |
# |   Average GPU Power Usage    |   9.368 W    |
# | Inference Energy Consumption | 0.077035 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_10/model.json
# INFO     Post calibration analysis complete.
# W0315 02:21:38.361274 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6384 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.362315 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1815 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.362808 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.4700 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363099 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2904 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363385 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.2549 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363618 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2525 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363879 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.1755 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364109 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2498 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364330 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.1552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364542 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2537 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364771 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.9494 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365005 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365243 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3049 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365498 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365726 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=7.9494 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366071 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4401 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366341 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.1995 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366575 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2007 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366806 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367028 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1949 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367249 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.7997 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367468 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1651 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367899 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1052 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.368262 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1593 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.368669 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=6.7997 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369010 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3283 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369326 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.6513 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369634 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1263 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369944 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1650 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.370243 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1284 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.370656 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4910 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.370944 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1042 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.371239 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.3105 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.371532 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0840 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.371831 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=8.4910 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.372119 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2463 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.372408 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.2235 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.372699 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0714 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.373008 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4094 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.373312 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0719 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.373595 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.6309 calibrator=MaxCalibrator scale=1.0 quant)
# W0315 02:21:38.373790 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.9...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72868    |
# |      Average Precision       |   0.71952    |
# |        Average Recall        |   0.72268    |
# |       Average F1 Score       |    0.7203    |
# |         Average Loss         |   0.80705    |
# |       Average Latency        |  27.485 ms   |
# |   Average GPU Power Usage    |   10.18 W    |
# | Inference Energy Consumption | 0.077725 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_11/model.json
# INFO     Post calibration analysis complete.
# W0315 02:21:44.078727 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=3.0570 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.079337 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.2071 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.079652 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.8774 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.079928 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3663 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080175 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4204 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080457 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2896 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080696 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=9.6484 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080967 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2951 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081194 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2232 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081415 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2948 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081642 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.5421 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081875 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2492 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082105 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.3595 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082331 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2424 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082558 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=10.5421 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082784 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.5430 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.083009 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# ...
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:03, 41.78it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:03, 45.54it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:03, 47.20it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:03, 44.01it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:03, 44.88it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:03, 45.40it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:03, 43.46it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:03, 44.17it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:03, 44.15it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:03, 43.40it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:03, 43.34it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:03, 43.85it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:03, 44.09it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:03, 44.18it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:03, 43.69it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:03, 43.76it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:03, 43.80it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:03, 43.52it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:03, 43.73it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:03, 43.54it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:03, 43.83it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:03, 43.50it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:03, 43.71it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:03, 44.12it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:03, 43.95it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:02, 44.04it/s]
# Validation DataLoader 0:  17%|██▉              | 27/157 [00:00<00:02, 44.17it/s]
# Validation DataLoader 0:  18%|███              | 28/157 [00:00<00:02, 44.19it/s]
# Validation DataLoader 0:  18%|███▏             | 29/157 [00:00<00:02, 43.33it/s]
# Validation DataLoader 0:  19%|███▏             | 30/157 [00:00<00:02, 43.30it/s]
# Validation DataLoader 0:  20%|███▎             | 31/157 [00:00<00:02, 42.61it/s]
# Validation DataLoader 0:  20%|███▍             | 32/157 [00:00<00:02, 42.09it/s]
# Validation DataLoader 0:  21%|███▌             | 33/157 [00:00<00:02, 41.85it/s]
# Validation DataLoader 0:  22%|███▋             | 34/157 [00:00<00:02, 41.93it/s]
# Validation DataLoader 0:  22%|███▊             | 35/157 [00:00<00:02, 42.01it/s]
# Validation DataLoader 0:  66%|██████████▌     | 104/157 [00:02<00:01, 39.05it/s]
# Validation DataLoader 0:  67%|██████████▋     | 105/157 [00:02<00:01, 39.03it/s]
# Validation DataLoader 0:  68%|██████████▊     | 106/157 [00:02<00:01, 38.95it/s]
# Validation DataLoader 0:  68%|██████████▉     | 107/157 [00:02<00:01, 38.69it/s]
# Validation DataLoader 0:  69%|███████████     | 108/157 [00:02<00:01, 38.70it/s]
# Validation DataLoader 0:  69%|███████████     | 109/157 [00:02<00:01, 38.70it/s]
# Validation DataLoader 0:  70%|███████████▏    | 110/157 [00:02<00:01, 38.64it/s]
# Validation DataLoader 0:  71%|███████████▎    | 111/157 [00:02<00:01, 38.65it/s]
# Validation DataLoader 0:  71%|███████████▍    | 112/157 [00:02<00:01, 38.65it/s]
# Validation DataLoader 0:  72%|███████████▌    | 113/157 [00:02<00:01, 38.63it/s]
# Validation DataLoader 0:  73%|███████████▌    | 114/157 [00:02<00:01, 38.57it/s]
# Validation DataLoader 0:  73%|███████████▋    | 115/157 [00:02<00:01, 38.46it/s]
# Validation DataLoader 0:  74%|███████████▊    | 116/157 [00:03<00:01, 38.47it/s]
# Validation DataLoader 0:  75%|███████████▉    | 117/157 [00:03<00:01, 38.48it/s]
# Validation DataLoader 0:  75%|████████████    | 118/157 [00:03<00:01, 38.49it/s]
# Validation DataLoader 0:  76%|████████████▏   | 119/157 [00:03<00:00, 38.32it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:03<00:00, 38.14it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:03<00:00, 38.20it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:03<00:00, 38.22it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:03<00:00, 38.19it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:03<00:00, 38.19it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:03<00:00, 38.22it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:03<00:00, 38.20it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:03<00:00, 38.23it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:03<00:00, 38.25it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:03<00:00, 38.28it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:03<00:00, 38.30it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:03<00:00, 38.33it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:03<00:00, 38.31it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:03<00:00, 38.36it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:03<00:00, 38.42it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:03<00:00, 38.39it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:03<00:00, 38.39it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:03<00:00, 38.36it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:03<00:00, 38.41it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:03<00:00, 38.41it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:03<00:00, 38.40it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:03<00:00, 38.37it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:03<00:00, 38.33it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:03<00:00, 38.33it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:03<00:00, 38.37it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:03<00:00, 38.39it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:04<00:00, 38.39it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:04<00:00, 38.43it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:04<00:00, 38.43it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:04<00:00, 38.34it/s]
# Epoch 1: 100%|█| 782/782 [00:35<00:00, 22.01it/s, v_num=13, train_acc_step=0.125I0315 02:24:27.561993 140494406755392 rank_zero.py:63] `Trainer.fit` stopped: `max_epochs=2` reached.
# Epoch 1: 100%|█| 782/782 [00:35<00:00, 21.88it/s, v_num=13, train_acc_step=0.125
# INFO     Fine Tuning Complete
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_17/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_18/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_19/model.json
# INFO     Running minimal runtime analysis on original graph (just 1 batch) ...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# |    Average Test Accuracy     |   0.68146   |
# |      Average Precision       |   0.7399    |
# |        Average Recall        |   0.70312   |
# |       Average F1 Score       |   0.70984   |
# |         Average Loss         |    0.895    |
# |       Average Latency        |  48.939 ms  |
# |   Average GPU Power Usage    |  8.1492 W   |
# | Inference Energy Consumption | 0.11078 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_15/model.json
# INFO     Measuring final TensorRT engine with warmup=20, test=500 ...
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-02:27:22] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.73975    |
# |      Average Precision       |   0.74038    |
# |        Average Recall        |   0.74242    |
# |       Average F1 Score       |   0.74044    |
# |         Average Loss         |   0.73944    |
# |       Average Latency        |   3.601 ms   |
# |   Average GPU Power Usage    |   13.729 W   |
# | Inference Energy Consumption | 0.013733 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_5/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %%
JSC_INT8_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_INT8_quant.toml"
JSC_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {JSC_INT8_BY_TYPE_TOML} --load {JSC_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 01:23:45.774668 139703610053696 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile', 'mse', 'entropy'], 'percentiles': [99.0, 99.9, 99.99], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': True}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     Applying fake quantization to PyTorch model...
# op is placeholder
# placeholder not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is max_pool2d
# max_pool2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is adaptive_avg_pool2d
# adaptive_avg_pool2d not in QUANTIZEABLE_OP
# op is flatten
# flatten not in QUANTIZEABLE_OP
# op is linear
# node.op == call_module
# op is output
# output not in QUANTIZEABLE_OP
# INFO     Fake quantization applied to PyTorch model.
# INFO     Quantized graph histogram:
# INFO
# | Original type     | OP                  |   Total |   Changed |   Unchanged |
# |-------------------+---------------------+---------+-----------+-------------|
# | AdaptiveAvgPool2d | adaptive_avg_pool2d |       1 |         0 |           1 |
# | BatchNorm2d       | batch_norm2d        |      20 |         0 |          20 |
# | MaxPool2d         | max_pool2d          |       1 |         0 |           1 |
# | QuantConv2d       | conv2d              |      20 |         0 |          20 |
# | QuantLinear       | linear              |       1 |         0 |           1 |
# | ReLU              | relu                |      17 |         0 |          17 |
# | add               | add                 |       8 |         0 |           8 |
# | flatten           | flatten             |       1 |         0 |           1 |
# | output            | output              |       1 |         0 |           1 |
# | x                 | placeholder         |       1 |         0 |           1 |
# INFO     Starting calibration of the model in PyTorch...
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.922260 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.922491 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.922657 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.922785 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.922956 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923104 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923228 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923357 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923478 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923589 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923706 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923818 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.923936 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924046 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924172 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924284 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924398 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924507 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924622 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924733 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924848 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.924958 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925071 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925192 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925306 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925416 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925532 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925656 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925778 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.925884 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926000 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926108 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926219 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926326 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926456 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926565 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926676 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926784 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.926894 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.927001 139703610053696 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.927117 139703610053696 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 01:23:58.927211 139703610053696 tensor_quantizer.py:174] Disable MaxCalibrator
# W0315 01:23:58.927518 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W0315 01:23:58.927609 139703610053696 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6224 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.927929 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1400 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.928180 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2234 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.928388 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2111 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.928645 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1065 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.928863 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1980 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.929070 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.8358 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.929276 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1957 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.929511 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1359 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.929744 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1970 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.929947 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.4627 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.930136 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1583 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.930328 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2610 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.930509 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1586 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.930694 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.4627 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.930871 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3493 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.931056 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5872 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.931236 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.931422 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2720 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.931605 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1517 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.931797 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.5370 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.931978 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1277 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.932162 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.6489 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.932338 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1132 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.932523 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=4.5370 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.932701 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2536 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.932884 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4016 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.933084 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.933270 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.3014 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.933448 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0944 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.933627 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.2608 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.933794 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0710 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.933966 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5874 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.934165 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0598 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.934376 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.2608 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.934560 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.1907 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.934740 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.9013 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.934911 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.935086 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.0223 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.935261 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:23:58.935403 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.6309 calibrator=MaxCalibrator scale=1.0 quant)
# W0315 01:23:58.935742 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.0...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# |    Average Test Accuracy     |   0.72608   |
# |      Average Precision       |   0.71486   |
# |        Average Recall        |   0.71875   |
# |       Average F1 Score       |   0.71577   |
# |         Average Loss         |   0.81619   |
# |       Average Latency        |  34.633 ms  |
# |   Average GPU Power Usage    |  13.806 W   |
# | Inference Energy Consumption | 0.13282 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_0/model.json
# INFO     Post calibration analysis complete.
# W0315 01:24:06.038734 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6384 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.039483 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1815 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.039825 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.4700 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.040095 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2904 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.040351 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.2549 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.040592 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2525 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.040854 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.1755 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.041092 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2498 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.041334 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.1552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.041567 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2537 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.041802 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.9494 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.042031 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.042269 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3049 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.042513 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.042753 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=7.9494 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.043049 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4401 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.043301 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.1995 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.043533 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2007 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.043810 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.044165 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1949 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.044557 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.7997 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.044898 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1651 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.045269 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1052 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.045599 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1593 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.045931 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=6.7997 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.046232 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3283 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.046531 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.6513 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.046845 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1263 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.047185 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1650 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.047479 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1284 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.047739 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4910 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.047980 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1042 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.048222 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.3105 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.048454 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0840 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.048927 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=8.4910 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.049339 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2463 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.049886 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.2235 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.050177 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0714 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.050515 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4094 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.050834 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0719 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:06.051083 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.6309 calibrator=MaxCalibrator scale=1.0 quant)
# W0315 01:24:06.051247 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.9...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72868    |
# |      Average Precision       |   0.71952    |
# |        Average Recall        |   0.72268    |
# |       Average F1 Score       |    0.7203    |
# |         Average Loss         |   0.80705    |
# |       Average Latency        |  28.964 ms   |
# |   Average GPU Power Usage    |   10.53 W    |
# | Inference Energy Consumption | 0.084719 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_1/model.json
# INFO     Post calibration analysis complete.
# W0315 01:24:11.926549 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=3.0570 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.927209 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.2071 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.927555 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.8774 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.927806 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3663 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.928054 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4204 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.928285 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2896 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.928526 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=9.6484 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.928769 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2951 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.929061 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2232 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.929307 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2948 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.929539 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.5421 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.929760 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2492 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.930126 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.3595 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.930378 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2424 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.930610 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=10.5421 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.930837 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.5430 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 01:24:11.931249 139703610053696 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# ...
# Epoch 1: 100%|█| 782/782 [00:37<00:00, 20.61it/s, v_num=12, train_acc_step=0.125
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:04, 34.99it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:05, 27.47it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:05, 28.20it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:04, 31.04it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:04, 32.71it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:04, 32.94it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:04, 33.94it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:04, 34.56it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:04, 34.76it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:04, 33.92it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:04, 33.71it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:04, 33.35it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:04, 33.58it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:04, 33.19it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:04, 32.51it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:04, 32.68it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:04, 32.37it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:04<00:01, 29.96it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:04<00:01, 29.87it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:04<00:01, 29.88it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:04<00:01, 29.89it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:04<00:01, 29.85it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:04<00:01, 29.79it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:04<00:01, 29.79it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:04<00:01, 29.75it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:04<00:00, 29.76it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:04<00:00, 29.77it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:04<00:00, 29.80it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:04<00:00, 29.80it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:04<00:00, 29.83it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:04<00:00, 29.80it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:04<00:00, 29.70it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:04<00:00, 29.69it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:04<00:00, 29.72it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:04<00:00, 29.72it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:04<00:00, 29.76it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:04<00:00, 29.79it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:04<00:00, 29.73it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:04<00:00, 29.74it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:04<00:00, 29.76it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:04<00:00, 29.75it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:04<00:00, 29.77it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:04<00:00, 29.78it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:04<00:00, 29.80it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:04<00:00, 29.79it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:04<00:00, 29.80it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:04<00:00, 29.80it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:05<00:00, 29.82it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:05<00:00, 29.84it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:05<00:00, 29.87it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:05<00:00, 29.89it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:05<00:00, 29.88it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:05<00:00, 29.89it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:05<00:00, 29.91it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:05<00:00, 29.89it/s]
# Epoch 1: 100%|█| 782/782 [00:43<00:00, 17.95it/s, v_num=12, train_acc_step=0.125I0315 01:27:10.410279 139703610053696 rank_zero.py:63] `Trainer.fit` stopped: `max_epochs=2` reached.
# Epoch 1: 100%|█| 782/782 [00:43<00:00, 17.84it/s, v_num=12, train_acc_step=0.125
# INFO     Fine Tuning Complete
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_1/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_2/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_3/model.json
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# | Average Validation Accuracy  |   0.73031   |
# |      Average Precision       |   0.72099   |
# |        Average Recall        |   0.72423   |
# |       Average F1 Score       |   0.7218    |
# |         Average Loss         |   0.81107   |
# |       Average Latency        |  42.757 ms  |
# |   Average GPU Power Usage    |  9.3992 W   |
# | Inference Energy Consumption | 0.11163 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_5/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-01:30:18] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.74089    |
# |      Average Precision       |   0.74216    |
# |        Average Recall        |   0.74431    |
# |       Average F1 Score       |   0.74236    |
# |         Average Loss         |    0.7364    |
# |       Average Latency        |  4.4764 ms   |
# |   Average GPU Power Usage    |   12.884 W   |
# | Inference Energy Consumption | 0.016021 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_0/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %%
JSC_FP16_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_FP16_quant.toml"
JSC_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {JSC_FP16_BY_TYPE_TOML} --load {JSC_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 01:36:29.907291 139755539158080 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 0, 'post_calibration_analysis': False, 'default': {'config': {'quantize': False, 'precision': 'fp16'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': False}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     precision=fp16, skipping int8 calibration/fine-tune...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_7/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_8/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_9/model.json
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72852    |
# |      Average Precision       |   0.71886    |
# |        Average Recall        |   0.72227    |
# |       Average F1 Score       |   0.71961    |
# |         Average Loss         |   0.80975    |
# |       Average Latency        |  8.0633 ms   |
# |   Average GPU Power Usage    |   13.007 W   |
# | Inference Energy Consumption | 0.029134 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_7/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-01:36:52] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.74178    |
# |      Average Precision       |    0.7423     |
# |        Average Recall        |    0.74514    |
# |       Average F1 Score       |    0.74268    |
# |         Average Loss         |    0.73414    |
# |       Average Latency        |   1.0096 ms   |
# |   Average GPU Power Usage    |   9.6732 W    |
# | Inference Energy Consumption | 0.0027127 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_2/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %%
JSC_FP32_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_FP32_quant.toml"
JSC_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {JSC_FP32_BY_TYPE_TOML} --load {JSC_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 01:43:15.535419 140335826768960 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 0, 'post_calibration_analysis': False, 'default': {'config': {'quantize': False, 'precision': 'fp32'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': False}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     precision=fp32, skipping int8 calibration/fine-tune...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_13/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_14/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_15/model.json
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72852    |
# |      Average Precision       |   0.71886    |
# |        Average Recall        |   0.72227    |
# |       Average F1 Score       |   0.71961    |
# |         Average Loss         |   0.80975    |
# |       Average Latency        |  8.3068 ms   |
# |   Average GPU Power Usage    |   17.661 W   |
# | Inference Energy Consumption | 0.040752 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_9/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-01:43:32] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.74162    |
# |      Average Precision       |    0.74235    |
# |        Average Recall        |    0.74514    |
# |       Average F1 Score       |    0.7427     |
# |         Average Loss         |    0.73414    |
# |       Average Latency        |   2.706 ms    |
# |   Average GPU Power Usage    |   11.678 W    |
# | Inference Energy Consumption | 0.0087779 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_4/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %% [markdown]
# As you can see, `fp16` acheives a slighty higher test accuracy but a slightly lower latency (~30%) from that of int8 quantization; it is still ~2.5x faster than the unquantized model. Now lets apply quantization to a more complicated model.
#
# ## Section 3. Type-wise Mixed Precision on Larger Model
# We will now quantize `vgg7` which includes both convolutional and linear layers, however for this demonstration we want to quantize all layer types except the linear layers.
#
# In this case, we set:
#
# - The `by` parameter to `type`
# - The `quantize` parameter to true for `passes.tensorrt.conv2d.config` and `precision` parameter to 'int8'.
# - The `input` and `weight` quantize axis for the conv2d layers.
# - The default `passes.tensorrt.default.config` precision to true.
#
# During the TensorRT quantization, the model's conv2d layers will be converted to an int8 fake quantized form, whilst the linear layers are kept to their default 'fp16'. Calibration of the conv2d layers and then fine tuning will be undergone before quantization and inference.
#
# You may either download a pretrained model [here](https://imperiallondon-my.sharepoint.com/:f:/g/personal/zz7522_ic_ac_uk/Emh3VT7Q_qRFmnp8kDrcgDoBwGUuzLwwKNtX8ZAt368jJQ?e=gsKONa), otherwise train it yourself as shown below.

# %%
VGG_TYPEWISE_TOML = "vgg7_typewise_mixed_precision.toml"

# !python /root/local/mase-gp/src/ch train --config {VGG_TYPEWISE_TOML}
# Out:
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0306 15:06:31.029283 140282827188032 seed.py:54] Seed set to 0
# +-------------------------+----------------------+--------------+-----------------+----------------------+
# | Name                    |       Default        | Config. File | Manual Override |      Effective       |
# +-------------------------+----------------------+--------------+-----------------+----------------------+
# | task                    |    classification    |     cls      |                 |         cls          |
# | load_name               |         None         |              |                 |         None         |
# | load_type               |          mz          |              |                 |          mz          |
# | batch_size              |         128          |      64      |                 |          64          |
# | to_debug                |        False         |              |                 |        False         |
# | log_level               |         info         |              |                 |         info         |
# | report_to               |     tensorboard      |              |                 |     tensorboard      |
# | seed                    |          0           |              |                 |          0           |
# | quant_config            |         None         |              |                 |         None         |
# | training_optimizer      |         adam         |              |                 |         adam         |
# | trainer_precision       |       16-mixed       |              |                 |       16-mixed       |
# | learning_rate           |        1e-05         |    0.001     |                 |        0.001         |
# | weight_decay            |          0           |              |                 |          0           |
# | max_epochs              |          20          |      10      |                 |          10          |
# | max_steps               |          -1          |              |                 |          -1          |
# | accumulate_grad_batches |          1           |              |                 |          1           |
# | log_every_n_steps       |          50          |              |                 |          50          |
# | num_workers             |          20          |              |                 |          20          |
# | num_devices             |          1           |              |                 |          1           |
# | num_nodes               |          1           |              |                 |          1           |
# | accelerator             |         auto         |     gpu      |                 |         gpu          |
# | strategy                |         auto         |              |                 |         auto         |
# | is_to_auto_requeue      |        False         |              |                 |        False         |
# | github_ci               |        False         |              |                 |        False         |
# | disable_dataset_cache   |        False         |              |                 |        False         |
# | target                  | xcu250-figd2104-2L-e |              |                 | xcu250-figd2104-2L-e |
# | num_targets             |         100          |              |                 |         100          |
# | is_pretrained           |        False         |              |                 |        False         |
# | max_token_len           |         512          |              |                 |         512          |
# | project_dir             |  /root/local/mase-   |              |                 |  /root/local/mase-   |
# |                         |    gp/mase_output    |              |                 |    gp/mase_output    |
# | project                 |         None         |              |                 |         None         |
# | model                   |         None         |  vgg7_cifar  |                 |      vgg7_cifar      |
# | dataset                 |         None         |   cifar10    |                 |       cifar10        |
# | t_max                   |          20          |              |                 |          20          |
# | eta_min                 |        1e-06         |              |                 |        1e-06         |
# +-------------------------+----------------------+--------------+-----------------+----------------------+
# INFO     Initialising model 'vgg7_cifar'...
# self.args.model is vgg7_cifar
# model_info is MaseModelInfo(name='vgg7_cifar', model_source=<ModelSource.VISION_OTHERS: 'vision_others'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /root/local/mase-gp/mase_output/vgg7_cifar_cls_cifar10_2025-03-06
# INFO     Training model 'vgg7_cifar'...
# INFO     ##### WEIGHT DECAY ##### 0
# I0306 15:06:32.428992 140282827188032 rank_zero.py:53] Using 16bit Automatic Mixed Precision (AMP)
# I0306 15:06:32.450018 140282827188032 rank_zero.py:53] GPU available: True (cuda), used: True
# I0306 15:06:32.556042 140282827188032 rank_zero.py:53] TPU available: False, using: 0 TPU cores
# I0306 15:06:32.556262 140282827188032 rank_zero.py:53] IPU available: False, using: 0 IPUs
# I0306 15:06:32.556331 140282827188032 rank_zero.py:53] HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# I0306 15:07:33.638568 140282827188032 cuda.py:58] LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# I0306 15:07:33.643197 140282827188032 model_summary.py:90]
#   | Name      | Type               | Params
# -------------------------------------------------
# 0 | model     | VGG7               | 14.0 M
# 1 | loss_fn   | CrossEntropyLoss   | 0
# 2 | acc_train | MulticlassAccuracy | 0
# 3 | loss_val  | MeanMetric         | 0
# 4 | loss_test | MeanMetric         | 0
# -------------------------------------------------
# 14.0 M    Trainable params
# 0         Non-trainable params
# 14.0 M    Total params
# 56.118    Total estimated model params size (MB)
# Epoch 0: 100%|█| 782/782 [00:24<00:00, 31.63it/s, v_num=1, train_acc_step=0.250]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:02, 70.71it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:02, 75.76it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:02, 52.80it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:02, 60.02it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:02, 63.17it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:03, 42.84it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:03, 45.56it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:03, 48.93it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:02, 52.03it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:02, 54.73it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:02, 57.33it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:02, 52.17it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:02, 54.23it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:02, 53.14it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:02, 54.86it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:02, 56.43it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:02, 57.91it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:02, 59.17it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:02, 60.43it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:02, 61.72it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:02, 62.94it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:02, 64.04it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:02, 65.05it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:02, 66.04it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:01, 67.07it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:01, 67.96it/s]
# Validation DataLoader 0:  17%|██▉              | 27/157 [00:00<00:01, 68.73it/s]
# Validation DataLoader 0:  18%|███              | 28/157 [00:00<00:01, 69.36it/s]
# Validation DataLoader 0:  18%|███▏             | 29/157 [00:00<00:01, 70.12it/s]
# Validation DataLoader 0:  19%|███▏             | 30/157 [00:00<00:01, 70.84it/s]
# Validation DataLoader 0:  20%|███▎             | 31/157 [00:00<00:01, 71.52it/s]
/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:01<00:00, 76.46it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:01<00:00, 76.44it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:01<00:00, 76.47it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:01<00:00, 76.51it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:01<00:00, 76.54it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:01<00:00, 76.57it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:01<00:00, 76.57it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:01<00:00, 76.58it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:01<00:00, 76.59it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:01<00:00, 76.58it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:01<00:00, 76.59it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:01<00:00, 76.63it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:01<00:00, 76.66it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:01<00:00, 76.68it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:01<00:00, 76.69it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:01<00:00, 76.66it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:01<00:00, 76.62it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:02<00:00, 76.64it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:02<00:00, 76.66it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:02<00:00, 76.66it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:02<00:00, 76.71it/s]
# Epoch 1: 100%|█| 782/782 [00:24<00:00, 31.30it/s, v_num=1, train_acc_step=0.250,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:01, 78.84it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:01, 89.66it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:01, 90.50it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:03, 48.86it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:02, 54.23it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:02, 58.67it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:02, 58.00it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:02, 61.44it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:02, 64.03it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:02, 66.41it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:02, 69.02it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:02, 71.18it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:02, 71.39it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:02, 69.59it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:02, 70.89it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:01, 72.06it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:01, 73.26it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:01<00:00, 79.21it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:01<00:00, 79.20it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:01<00:00, 79.25it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:01<00:00, 79.25it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:01<00:00, 79.20it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:01<00:00, 79.21it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:01<00:00, 79.24it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:01<00:00, 79.23it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:01<00:00, 79.23it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:01<00:00, 79.14it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:01<00:00, 79.15it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:01<00:00, 79.20it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:01<00:00, 79.24it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:01<00:00, 79.26it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:01<00:00, 79.24it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:01<00:00, 79.22it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:01<00:00, 79.21it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:01<00:00, 79.22it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:01<00:00, 79.23it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:01<00:00, 79.22it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:01<00:00, 79.23it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:01<00:00, 79.20it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:01<00:00, 79.21it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:01<00:00, 79.29it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:01<00:00, 79.32it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:01<00:00, 79.35it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:01<00:00, 79.39it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:01<00:00, 79.43it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:01<00:00, 79.42it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:01<00:00, 79.44it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:01<00:00, 79.42it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:01<00:00, 79.41it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:01<00:00, 79.47it/s]
# Epoch 2: 100%|█| 782/782 [00:24<00:00, 31.84it/s, v_num=1, train_acc_step=0.250,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:02, 73.55it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:02, 62.88it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:05, 27.17it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:04, 33.16it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:03, 38.17it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:03, 42.56it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:03, 44.75it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:03, 48.25it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:02, 51.35it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:02, 54.28it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:02, 56.77it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:02, 59.09it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:02, 61.14it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:02, 62.84it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:02, 64.42it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:02, 65.82it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:02, 67.37it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:02, 68.67it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:01, 69.99it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:01, 71.12it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:01, 72.16it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:01, 73.23it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:01, 69.43it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:01, 70.50it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:01, 71.50it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:01, 72.42it/s]
# Validation DataLoader 0:  17%|██▉              | 27/157 [00:00<00:01, 73.27it/s]
# Validation DataLoader 0:  18%|███              | 28/157 [00:00<00:01, 74.21it/s]
# Validation DataLoader 0:  18%|███▏             | 29/157 [00:00<00:01, 75.08it/s]
# Validation DataLoader 0:  19%|███▏             | 30/157 [00:00<00:01, 75.84it/s]
# Validation DataLoader 0:  20%|███▎             | 31/157 [00:00<00:01, 76.47it/s]
# Validation DataLoader 0:  20%|███▍             | 32/157 [00:00<00:01, 77.12it/s]
# Validation DataLoader 0:  21%|███▌             | 33/157 [00:00<00:01, 77.77it/s]
# Validation DataLoader 0:  22%|███▋             | 34/157 [00:00<00:01, 78.49it/s]
# Validation DataLoader 0:  22%|███▊             | 35/157 [00:00<00:01, 79.11it/s]
# Validation DataLoader 0:  23%|███▉             | 36/157 [00:00<00:01, 79.74it/s]
# Validation DataLoader 0:  24%|████             | 37/157 [00:00<00:01, 80.21it/s]
# Validation DataLoader 0:  68%|██████████▊     | 106/157 [00:01<00:00, 79.56it/s]
# Validation DataLoader 0:  68%|██████████▉     | 107/157 [00:01<00:00, 79.55it/s]
# Validation DataLoader 0:  69%|███████████     | 108/157 [00:01<00:00, 79.54it/s]
# Validation DataLoader 0:  69%|███████████     | 109/157 [00:01<00:00, 79.51it/s]
# Validation DataLoader 0:  70%|███████████▏    | 110/157 [00:01<00:00, 79.43it/s]
# Validation DataLoader 0:  71%|███████████▎    | 111/157 [00:01<00:00, 79.39it/s]
# Validation DataLoader 0:  71%|███████████▍    | 112/157 [00:01<00:00, 79.39it/s]
# Validation DataLoader 0:  72%|███████████▌    | 113/157 [00:01<00:00, 79.39it/s]
# Validation DataLoader 0:  73%|███████████▌    | 114/157 [00:01<00:00, 79.37it/s]
# Validation DataLoader 0:  73%|███████████▋    | 115/157 [00:01<00:00, 79.38it/s]
# Validation DataLoader 0:  74%|███████████▊    | 116/157 [00:01<00:00, 79.39it/s]
# Validation DataLoader 0:  75%|███████████▉    | 117/157 [00:01<00:00, 79.39it/s]
# Validation DataLoader 0:  75%|████████████    | 118/157 [00:01<00:00, 79.43it/s]
# Validation DataLoader 0:  76%|████████████▏   | 119/157 [00:01<00:00, 79.45it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:01<00:00, 79.51it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:01<00:00, 79.55it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:01<00:00, 79.59it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:01<00:00, 79.63it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:01<00:00, 79.43it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:01<00:00, 79.31it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:01<00:00, 79.26it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:01<00:00, 79.27it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:01<00:00, 79.23it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:01<00:00, 79.21it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:01<00:00, 79.18it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:01<00:00, 79.03it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:01<00:00, 78.98it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:01<00:00, 78.94it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:01<00:00, 78.94it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:01<00:00, 79.00it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:01<00:00, 78.99it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:01<00:00, 78.97it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:01<00:00, 78.97it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:01<00:00, 78.98it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:01<00:00, 79.01it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:01<00:00, 79.03it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:01<00:00, 79.04it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:01<00:00, 79.05it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:01<00:00, 79.05it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:01<00:00, 78.97it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:01<00:00, 78.97it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:01<00:00, 78.96it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:01<00:00, 78.90it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:01<00:00, 78.88it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:01<00:00, 78.85it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:01<00:00, 78.82it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:01<00:00, 78.83it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:01<00:00, 78.86it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:01<00:00, 78.88it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:01<00:00, 78.90it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:01<00:00, 78.98it/s]
# Epoch 3: 100%|█| 782/782 [00:24<00:00, 31.84it/s, v_num=1, train_acc_step=0.625,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:01, 78.03it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:03, 41.89it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:02, 52.00it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:02, 59.45it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:02, 64.61it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:02, 68.38it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:02, 71.70it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:01, 74.66it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:01, 76.92it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:01, 78.78it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:01, 80.69it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:01, 82.17it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:01, 83.08it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:01, 84.18it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:01, 85.17it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:01, 86.14it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:01, 86.63it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:01, 87.35it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:01, 78.08it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:01, 78.96it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:01, 79.62it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:01, 80.22it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:01, 81.04it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:01, 81.72it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:01, 82.37it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:01, 82.21it/s]
# ...
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:01<00:00, 77.74it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:01<00:00, 77.74it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:01<00:00, 77.70it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:01<00:00, 77.66it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:01<00:00, 77.66it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:01<00:00, 77.66it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:01<00:00, 77.70it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:01<00:00, 77.68it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:01<00:00, 77.69it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:01<00:00, 77.69it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:01<00:00, 77.71it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:01<00:00, 77.70it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:01<00:00, 77.71it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:01<00:00, 77.76it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:01<00:00, 77.80it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:01<00:00, 77.82it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:01<00:00, 77.75it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:01<00:00, 77.74it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:01<00:00, 77.77it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:01<00:00, 77.79it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:01<00:00, 77.81it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:01<00:00, 77.83it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:01<00:00, 77.83it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:01<00:00, 77.80it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:01<00:00, 77.82it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:01<00:00, 77.85it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:01<00:00, 77.86it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:01<00:00, 77.72it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:01<00:00, 77.51it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:02<00:00, 77.49it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:02<00:00, 77.43it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:02<00:00, 77.48it/s]
# Epoch 9: 100%|█| 782/782 [00:25<00:00, 31.23it/s, v_num=1, train_acc_step=0.625,
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:01, 78.31it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:06, 25.15it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:04, 31.56it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:04, 31.54it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:04, 36.39it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:03, 39.40it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:03, 42.97it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:03, 46.13it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:03, 48.67it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:02, 51.26it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:02, 53.45it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:02, 55.39it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:02, 56.98it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:02, 58.74it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:02, 60.38it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:02, 61.91it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:02, 63.34it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:02, 64.57it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:02, 65.82it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:02, 67.02it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:02, 67.98it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:01, 69.00it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:01, 69.92it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:02, 66.22it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:01, 67.21it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:01, 67.49it/s]
# Validation DataLoader 0:  17%|██▉              | 27/157 [00:00<00:01, 68.29it/s]
# Validation DataLoader 0:  18%|███              | 28/157 [00:00<00:01, 68.93it/s]
# Validation DataLoader 0:  18%|███▏             | 29/157 [00:00<00:01, 69.65it/s]
# Validation DataLoader 0:  19%|███▏             | 30/157 [00:00<00:01, 70.31it/s]
# Validation DataLoader 0:  20%|███▎             | 31/157 [00:00<00:01, 70.90it/s]
# Validation DataLoader 0:  20%|███▍             | 32/157 [00:00<00:01, 71.55it/s]
# Validation DataLoader 0:  21%|███▌             | 33/157 [00:00<00:01, 72.22it/s]
# Validation DataLoader 0:  22%|███▋             | 34/157 [00:00<00:01, 72.84it/s]
# Validation DataLoader 0:  22%|███▊             | 35/157 [00:00<00:01, 73.44it/s]
# Validation DataLoader 0:  23%|███▉             | 36/157 [00:00<00:01, 73.93it/s]
# Validation DataLoader 0:  24%|████             | 37/157 [00:00<00:01, 74.46it/s]
# Validation DataLoader 0:  24%|████             | 38/157 [00:00<00:01, 75.04it/s]
# Validation DataLoader 0:  25%|████▏            | 39/157 [00:00<00:01, 75.56it/s]
# Validation DataLoader 0:  25%|████▎            | 40/157 [00:00<00:01, 76.10it/s]
# Validation DataLoader 0:  69%|███████████     | 109/157 [00:01<00:00, 75.88it/s]
# Validation DataLoader 0:  70%|███████████▏    | 110/157 [00:01<00:00, 75.94it/s]
# Validation DataLoader 0:  71%|███████████▎    | 111/157 [00:01<00:00, 75.94it/s]
# Validation DataLoader 0:  71%|███████████▍    | 112/157 [00:01<00:00, 75.94it/s]
# Validation DataLoader 0:  72%|███████████▌    | 113/157 [00:01<00:00, 75.93it/s]
# Validation DataLoader 0:  73%|███████████▌    | 114/157 [00:01<00:00, 75.97it/s]
# Validation DataLoader 0:  73%|███████████▋    | 115/157 [00:01<00:00, 76.00it/s]
# Validation DataLoader 0:  74%|███████████▊    | 116/157 [00:01<00:00, 76.00it/s]
# Validation DataLoader 0:  75%|███████████▉    | 117/157 [00:01<00:00, 75.98it/s]
# Validation DataLoader 0:  75%|████████████    | 118/157 [00:01<00:00, 75.98it/s]
# Validation DataLoader 0:  76%|████████████▏   | 119/157 [00:01<00:00, 75.99it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:01<00:00, 76.02it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:01<00:00, 76.01it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:01<00:00, 75.98it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:01<00:00, 75.97it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:01<00:00, 76.00it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:01<00:00, 76.02it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:01<00:00, 76.05it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:01<00:00, 76.08it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:01<00:00, 76.09it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:01<00:00, 76.08it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:01<00:00, 76.11it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:01<00:00, 76.12it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:01<00:00, 76.14it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:01<00:00, 76.12it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:01<00:00, 76.15it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:01<00:00, 76.15it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:01<00:00, 76.19it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:01<00:00, 76.23it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:01<00:00, 76.27it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:01<00:00, 76.34it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:01<00:00, 76.36it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:01<00:00, 76.35it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:01<00:00, 76.35it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:01<00:00, 76.38it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:01<00:00, 76.38it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:01<00:00, 76.42it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:01<00:00, 76.47it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:01<00:00, 76.50it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:01<00:00, 76.51it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:01<00:00, 76.54it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:01<00:00, 76.54it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:01<00:00, 76.56it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:01<00:00, 76.56it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:02<00:00, 76.49it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:02<00:00, 76.40it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:02<00:00, 76.42it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:02<00:00, 76.44it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:02<00:00, 76.48it/s]
# Epoch 9: 100%|█| 782/782 [00:27<00:00, 28.21it/s, v_num=1, train_acc_step=0.625,I0306 15:13:40.852709 140282827188032 rank_zero.py:53] `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|█| 782/782 [00:35<00:00, 21.99it/s, v_num=1, train_acc_step=0.625,
# INFO     Training is completed

# %% [markdown]
# We will now load the checkpoint in, quantize the model and compare it to the unquantized version as we did in [Section 1.5](#section-15-performance-analysis)

# %%
VGG_TYPEWISE_TOML = "vgg7_typewise_mixed_precision.toml"
# Change this checkpoint path accordingly
VGG_CHECKPOINT_PATH = "/root/local/mase-gp/mase_output/vgg7_cifar_cls_cifar10_2025-03-06/software/training_ckpts/best.ckpt"

# %%
# !python /root/local/mase-gp/src/ch transform --config {VGG_TYPEWISE_TOML} --load {VGG_CHECKPOINT_PATH} --load-type pl
# Out:
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0306 15:58:00.578649 140271219853120 seed.py:54] Seed set to 0
# +-------------------------+----------------------+--------------+--------------------------+--------------------------+
# | Name                    |       Default        | Config. File |     Manual Override      |        Effective         |
# +-------------------------+----------------------+--------------+--------------------------+--------------------------+
# | task                    |    classification    |     cls      |                          |           cls            |
# | load_name               |         None         |              | /root/local/mase-gp/mase | /root/local/mase-gp/mase |
# |                         |                      |              | _output/vgg7_cifar_cls_c | _output/vgg7_cifar_cls_c |
# |                         |                      |              | ifar10_2025-03-06/softwa | ifar10_2025-03-06/softwa |
# |                         |                      |              | re/training_ckpts/best.c | re/training_ckpts/best.c |
# |                         |                      |              |           kpt            |           kpt            |
# | load_type               |          mz          |              |            pl            |            pl            |
# | batch_size              |         128          |      64      |                          |            64            |
# | to_debug                |        False         |              |                          |          False           |
# | log_level               |         info         |              |                          |           info           |
# | report_to               |     tensorboard      |              |                          |       tensorboard        |
# | seed                    |          0           |              |                          |            0             |
# | quant_config            |         None         |              |                          |           None           |
# | training_optimizer      |         adam         |              |                          |           adam           |
# | trainer_precision       |       16-mixed       |              |                          |         16-mixed         |
# | learning_rate           |        1e-05         |    0.001     |                          |          0.001           |
# | weight_decay            |          0           |              |                          |            0             |
# | max_epochs              |          20          |      10      |                          |            10            |
# | max_steps               |          -1          |              |                          |            -1            |
# | accumulate_grad_batches |          1           |              |                          |            1             |
# | log_every_n_steps       |          50          |              |                          |            50            |
# | num_workers             |          20          |              |                          |            20            |
# | num_devices             |          1           |              |                          |            1             |
# | num_nodes               |          1           |              |                          |            1             |
# | accelerator             |         auto         |     gpu      |                          |           gpu            |
# | strategy                |         auto         |              |                          |           auto           |
# | is_to_auto_requeue      |        False         |              |                          |          False           |
# | github_ci               |        False         |              |                          |          False           |
# | disable_dataset_cache   |        False         |              |                          |          False           |
# | target                  | xcu250-figd2104-2L-e |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |         100          |              |                          |           100            |
# | is_pretrained           |        False         |              |                          |          False           |
# | max_token_len           |         512          |              |                          |           512            |
# | project_dir             |  /root/local/mase-   |              |                          |    /root/local/mase-     |
# |                         |    gp/mase_output    |              |                          |      gp/mase_output      |
# | project                 |         None         |              |                          |           None           |
# | model                   |         None         |  vgg7_cifar  |                          |        vgg7_cifar        |
# | dataset                 |         None         |   cifar10    |                          |         cifar10          |
# | t_max                   |          20          |              |                          |            20            |
# | eta_min                 |        1e-06         |              |                          |          1e-06           |
# +-------------------------+----------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'vgg7_cifar'...
# self.args.model is vgg7_cifar
# model_info is MaseModelInfo(name='vgg7_cifar', model_source=<ModelSource.VISION_OTHERS: 'vision_others'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /root/local/mase-gp/mase_output/vgg7_cifar_cls_cifar10_2025-03-06
# INFO     Transforming model 'vgg7_cifar'...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# INFO     Loaded pytorch lightning checkpoint from /root/local/mase-gp/mase_output/vgg7_cifar_cls_cifar10_2025-03-06/software/training_ckpts/best.ckpt
# {'model': 'vgg7_cifar', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile'], 'percentiles': [99.0, 99.9], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'linear': {'config': {'quantize': False}}, 'conv2d': {'config': {'quantize': True, 'precision': 'int8', 'calibrator': 'histogram'}, 'input': {'quantize_axis': False}, 'weight': {'quantize_axis': False}}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /root/local/mase-gp/mase_output/vgg7_cifar_cls_cifar10_2025-03-06/software/training_ckpts/best.ckpt
# tensor([[[[3.4464e-01, 6.9910e-01, 6.0161e-01, 5.1311e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#           [6.6311e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#           [7.8461e-01, 4.2010e-01, 0.0000e+00, 0.0000e+00]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 1
-01, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#           [1.9086e-01, 1.4497e-01, 1.7847e-01, 0.0000e+00],
#           [4.2632e-01, 1.2138e+00, 8.4704e-01, 0.0000e+00]],
#
#          [[4.0809e-01, 0.0000e+00, 2.1326e-01, 3.9940e-01],
#           [5.2010e-01, 6.7214e-03, 3.6464e-01, 5.8390e-01],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]],
#
#          ...,
#
#          [[0.0000e+00, 0.0000e+00, 4.8838e-01, 2.3755e-01],
#           [1.3527e-01, 0.0000e+00, 1.2194e-01, 0.0000e+00],
#           [1.0103e-01, 3.5915e-01, 0.0000e+00, 1.5934e-01],
#           [0.0000e+00, 1.3741e+00, 1.6263e+00, 6.2613e-01]],
#
#          [[0.0000e+00, 0.0000e+00, 2.2307e-01, 9.2222e-02],
#           [6.4332e-01, 1.3732e-01, 1.2238e+00, 5.5892e-01],
#           [1.7521e-01, 2.3195e-01, 4.3394e-01, 3.9164e-01],
#           [0.0000e+00, 0.0000e+00, 5.9715e-01, 6.8072e-01]],
#
#          [[4.6217e-01, 6.5594e-01, 7.3069e-01, 8.3431e-01],
#           [0.0000e+00, 0.0000e+00, 9.2466e-01, 1.2812e+00],
#           [1.0521e+00, 2.2856e-01, 0.0000e+00, 6.4906e-01],
#           [4.9690e-01, 3.0810e-01, 1.3593e+00, 1.1906e+00]]]], device='cuda:0',
#        grad_fn=<MaxPool2DWithIndicesBackward0>)

# %% [markdown]
# By quantizing all convolutional layers to INT8 and maintaining fp16 precision for the linear layers we see a marginal decrease in latency whilst maintaining a comparable accuracy. By experimenting with precisions on a per type basis, you may find insights that work best for your model.
#
# ## Section 4. Layer-wise Mixed Precision
#
# So far we have strictly quantized either in int8 or fp16. Now, we will show how to conduct layerwise mixed precision using the same `vgg7` model. In this case we will show how for instance, layer 0 and 1 can be set to fp16, while the remaining layers can be int8 quantized.
#
# For this, we set:
# - The `by` parameter to `name`
# - The `precision` to 'int8' for `passes.tensorrt.default.config`
# - The `precision` to 'fp16' for `passes.tensorrt.feature_layers_0.config and passes.tensorrt.feature_layers_1.config`
# - The `precision` to 'int8' for `passes.tensorrt.feature_layers_2.config and passes.tensorrt.feature_layers_3.config` (although this is not necessary since the default is already set to 'int8')

# %%
VGG_LAYERWISE_TOML = "../../../machop/configs/tensorrt/vgg7_layerwise_mixed_precision.toml"

# !python /root/local/mase-gp/src/ch transform --config {VGG_LAYERWISE_TOML} --load {VGG_CHECKPOINT_PATH} --load-type pl
# Out:
# [2024-03-28 23:25:51,157] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0328 23:25:54.303634 140449214740288 seed.py:54] Seed set to 0
# +-------------------------+------------------------+--------------+--------------------------+--------------------------+
# | Name                    |        Default         | Config. File |     Manual Override      |        Effective         |
# +-------------------------+------------------------+--------------+--------------------------+--------------------------+
# | task                    |     classification     |     cls      |                          |           cls            |
# | load_name               |          None          |              | /root/mase/mase_output/v | /root/mase/mase_output/v |
# |                         |                        |              |  gg7-pre-trained/test-   |  gg7-pre-trained/test-   |
# |                         |                        |              |     accu-0.9332.ckpt     |     accu-0.9332.ckpt     |
# | load_type               |           mz           |              |            pl            |            pl            |
# | batch_size              |          128           |      64      |                          |            64            |
# | to_debug                |         False          |              |                          |          False           |
# | log_level               |          info          |              |                          |           info           |
# | report_to               |      tensorboard       |              |                          |       tensorboard        |
# | seed                    |           0            |              |                          |            0             |
# | quant_config            |          None          |              |                          |           None           |
# | training_optimizer      |          adam          |              |                          |           adam           |
# | trainer_precision       |        16-mixed        |              |                          |         16-mixed         |
# | learning_rate           |         1e-05          |    0.001     |                          |          0.001           |
# | weight_decay            |           0            |              |                          |            0             |
# | max_epochs              |           20           |      10      |                          |            10            |
# | max_steps               |           -1           |              |                          |            -1            |
# | accumulate_grad_batches |           1            |              |                          |            1             |
# | log_every_n_steps       |           50           |              |                          |            50            |
# | num_workers             |           28           |              |                          |            28            |
# | num_devices             |           1            |              |                          |            1             |
# | num_nodes               |           1            |              |                          |            1             |
# | accelerator             |          auto          |     gpu      |                          |           gpu            |
# | strategy                |          auto          |              |                          |           auto           |
# | is_to_auto_requeue      |         False          |              |                          |          False           |
# | github_ci               |         False          |              |                          |          False           |
# | disable_dataset_cache   |         False          |              |                          |          False           |
# | target                  |  xcu250-figd2104-2L-e  |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |          100           |              |                          |           100            |
# | is_pretrained           |         False          |              |                          |          False           |
# | max_token_len           |          512           |              |                          |           512            |
# | project_dir             | /root/mase/mase_output |              |                          |  /root/mase/mase_output  |
# | project                 |          None          |              |                          |           None           |
# | model                   |          None          |     vgg7     |                          |           vgg7           |
# | dataset                 |          None          |   cifar10    |                          |         cifar10          |
# | t_max                   |           20           |              |                          |            20            |
# | eta_min                 |         1e-06          |              |                          |          1e-06           |
# +-------------------------+------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'vgg7'...
# I0328 23:25:54.313626 140449214740288 cli.py:846] Initialising model 'vgg7'...
# INFO     Initialising dataset 'cifar10'...
# I0328 23:25:54.417618 140449214740288 cli.py:874] Initialising dataset 'cifar10'...
# INFO     Project will be created at /root/mase/mase_output/vgg7_cls_cifar10_2024-03-28
# I0328 23:25:54.418019 140449214740288 cli.py:910] Project will be created at /root/mase/mase_output/vgg7_cls_cifar10_2024-03-28
# INFO     Transforming model 'vgg7'...
# I0328 23:25:54.535444 140449214740288 cli.py:370] Transforming model 'vgg7'...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# INFO     Loaded pytorch lightning checkpoint from /root/mase/mase_output/vgg7-pre-trained/test-accu-0.9332.ckpt
# I0328 23:26:00.655963 140449214740288 checkpoint_load.py:85] Loaded pytorch lightning checkpoint from /root/mase/mase_output/vgg7-pre-trained/test-accu-0.9332.ckpt
# INFO     Loaded pytorch lightning checkpoint from /root/mase/mase_output/vgg7-pre-trained/test-accu-0.9332.ckpt
# I0328 23:26:00.777872 140449214740288 checkpoint_load.py:85] Loaded pytorch lightning checkpoint from /root/mase/mase_output/vgg7-pre-trained/test-accu-0.9332.ckpt
# INFO     Applying fake quantization to PyTorch model...
# I0328 23:26:12.570783 140449214740288 utils.py:314] Applying fake quantization to PyTorch model...
# INFO     Fake quantization applied to PyTorch model.
# I0328 23:26:12.921518 140449214740288 utils.py:339] Fake quantization applied to PyTorch model.
# INFO     Quantized graph histogram:
# I0328 23:26:12.940881 140449214740288 summary.py:84] Quantized graph histogram:
# INFO
# | Original type   | OP           |   Total |   Changed |   Unchanged |
# |-----------------+--------------+---------+-----------+-------------|
# | BatchNorm2d     | batch_norm2d |       6 |         0 |           6 |
# | Conv2d          | conv2d       |       6 |         5 |           1 |
# | Linear          | linear       |       3 |         3 |           0 |
# | MaxPool2d       | max_pool2d   |       3 |         0 |           3 |
# | ReLU            | relu         |       8 |         0 |           8 |
# | output          | output       |       1 |         0 |           1 |
# | view            | view         |       1 |         0 |           1 |
# | x               | placeholder  |       1 |         0 |           1 |
# I0328 23:26:12.941653 140449214740288 summary.py:85]
# | Original type   | OP           |   Total |   Changed |   Unchanged |
# |-----------------+--------------+---------+-----------+-------------|
# | BatchNorm2d     | batch_norm2d |       6 |         0 |           6 |
# | Conv2d          | conv2d       |       6 |         5 |           1 |
# | Linear          | linear       |       3 |         3 |           0 |
# | MaxPool2d       | max_pool2d   |       3 |         0 |           3 |
# | ReLU            | relu         |       8 |         0 |           8 |
# | output          | output       |       1 |         0 |           1 |
# | view            | view         |       1 |         0 |           1 |
# | x               | placeholder  |       1 |         0 |           1 |
# INFO     Starting calibration of the model in PyTorch...
# I0328 23:26:12.942434 140449214740288 calibrate.py:143] Starting calibration of the model in PyTorch...
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.952852 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953087 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953220 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953323 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953427 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953537 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953635 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953727 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953824 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.953913 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.954009 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.954101 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.954192 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.954295 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.954387 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# I0328 23:26:12.954478 140449214740288 calibrate.py:152] Disabling Quantization and Enabling Calibration
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.535559 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.535989 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.536076 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.536209 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.536275 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.536394 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.536448 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.536548 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.536605 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.536704 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.536756 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.536853 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.536910 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537009 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.537059 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537172 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.537243 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537340 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.537401 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537500 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.537567 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537664 140449214740288 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.537712 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537806 140449214740288 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.537872 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.537964 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.538011 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.538102 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.538153 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.538257 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# I0328 23:26:18.538305 140449214740288 calibrate.py:175] Enabling Quantization and Disabling Calibration
# W0328 23:26:18.538399 140449214740288 tensor_quantizer.py:174] Disable HistogramCalibrator
# W0328 23:26:18.546847 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W0328 23:26:18.546956 140449214740288 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# INFO     feature_layers.3._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=3.2937 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.547093 140449214740288 calibrate.py:131] feature_layers.3._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=3.2937 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.547413 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.3._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.2366 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.547523 140449214740288 calibrate.py:131] feature_layers.3._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.2366 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.547886 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.7._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=1.8330 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.548011 140449214740288 calibrate.py:131] feature_layers.7._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=1.8330 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.548304 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.7._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.2296 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.548407 140449214740288 calibrate.py:131] feature_layers.7._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.2296 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.548746 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.10._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=1.4681 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.548850 140449214740288 calibrate.py:131] feature_layers.10._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=1.4681 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.549174 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.10._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2080 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.549281 140449214740288 calibrate.py:131] feature_layers.10._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2080 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.549598 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.14._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=1.9284 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.549701 140449214740288 calibrate.py:131] feature_layers.14._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=1.9284 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.550004 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.14._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2013 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.550112 140449214740288 calibrate.py:131] feature_layers.14._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2013 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.550404 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.17._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=1.6127 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.550505 140449214740288 calibrate.py:131] feature_layers.17._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=1.6127 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.550795 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.17._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.1879 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.550894 140449214740288 calibrate.py:131] feature_layers.17._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.1879 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.551028 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     classifier.0._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=11.6545 calibrator=MaxCalibrator scale=1.0 quant)
# I0328 23:26:18.551139 140449214740288 calibrate.py:131] classifier.0._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=11.6545 calibrator=MaxCalibrator scale=1.0 quant)
# W0328 23:26:18.551264 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([1024, 1]).
# INFO     classifier.0._weight_quantizer          : TensorQuantizer(8bit fake axis=0 amax=[0.0158, 0.4703](1024) calibrator=MaxCalibrator scale=1.0 quant)
# I0328 23:26:18.551505 140449214740288 calibrate.py:131] classifier.0._weight_quantizer          : TensorQuantizer(8bit fake axis=0 amax=[0.0158, 0.4703](1024) calibrator=MaxCalibrator scale=1.0 quant)
# W0328 23:26:18.551799 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     classifier.2._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=9.7654 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.551900 140449214740288 calibrate.py:131] classifier.2._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=9.7654 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.552192 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     classifier.2._weight_quantizer          : TensorQuantizer(8bit fake per-tensor amax=0.0590 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.552289 140449214740288 calibrate.py:131] classifier.2._weight_quantizer          : TensorQuantizer(8bit fake per-tensor amax=0.0590 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.552608 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     last_layer._input_quantizer             : TensorQuantizer(8bit fake per-tensor amax=7.4475 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.552708 140449214740288 calibrate.py:131] last_layer._input_quantizer             : TensorQuantizer(8bit fake per-tensor amax=7.4475 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:18.552994 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     last_layer._weight_quantizer            : TensorQuantizer(8bit fake per-tensor amax=0.1019 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:18.553097 140449214740288 calibrate.py:131] last_layer._weight_quantizer            : TensorQuantizer(8bit fake per-tensor amax=0.1019 calibrator=HistogramCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.0...
# I0328 23:26:18.554053 140449214740288 calibrate.py:105] Performing post calibration analysis for calibrator percentile_99.0...
# INFO     Starting transformation analysis on vgg7
# I0328 23:26:18.554283 140449214740288 runtime_analysis.py:357] Starting transformation analysis on vgg7
# INFO
# Results vgg7:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# |    Average Test Accuracy     |   0.87663   |
# |      Average Precision       |   0.87531   |
# |        Average Recall        |   0.87386   |
# |       Average F1 Score       |   0.87335   |
# |         Average Loss         |   0.65133   |
# |       Average Latency        |  17.901 ms  |
# |   Average GPU Power Usage    |  57.532 W   |
# | Inference Energy Consumption | 0.28607 mWh |
# +------------------------------+-------------+
# I0328 23:26:29.263397 140449214740288 runtime_analysis.py:521]
# Results vgg7:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# |    Average Test Accuracy     |   0.87663   |
# |      Average Precision       |   0.87531   |
# |        Average Recall        |   0.87386   |
# |       Average F1 Score       |   0.87335   |
# |         Average Loss         |   0.65133   |
# |       Average Latency        |  17.901 ms  |
# |   Average GPU Power Usage    |  57.532 W   |
# | Inference Energy Consumption | 0.28607 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/mase_graph/version_50/model.json
# I0328 23:26:29.264865 140449214740288 runtime_analysis.py:143] Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/mase_graph/version_50/model.json
# INFO     Post calibration analysis complete.
# I0328 23:26:29.265057 140449214740288 calibrate.py:118] Post calibration analysis complete.
# W0328 23:26:29.265783 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.3._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=5.9458 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.266022 140449214740288 calibrate.py:131] feature_layers.3._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=5.9458 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.266428 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.3._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.3704 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.266630 140449214740288 calibrate.py:131] feature_layers.3._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.3704 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.267089 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.7._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=3.2568 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.267289 140449214740288 calibrate.py:131] feature_layers.7._input_quantizer       : TensorQuantizer(8bit fake per-tensor amax=3.2568 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.267678 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.7._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.3621 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.267869 140449214740288 calibrate.py:131] feature_layers.7._weight_quantizer      : TensorQuantizer(8bit fake per-tensor amax=0.3621 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.268326 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.10._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=2.4123 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.268521 140449214740288 calibrate.py:131] feature_layers.10._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=2.4123 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.268913 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.10._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2821 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.269103 140449214740288 calibrate.py:131] feature_layers.10._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2821 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.269515 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.14._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=2.9841 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.269702 140449214740288 calibrate.py:131] feature_layers.14._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=2.9841 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.270093 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.14._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2734 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.270280 140449214740288 calibrate.py:131] feature_layers.14._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2734 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.270668 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.17._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=2.7013 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.270851 140449214740288 calibrate.py:131] feature_layers.17._input_quantizer      : TensorQuantizer(8bit fake per-tensor amax=2.7013 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.271238 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     feature_layers.17._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2519 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.271429 140449214740288 calibrate.py:131] feature_layers.17._weight_quantizer     : TensorQuantizer(8bit fake per-tensor amax=0.2519 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.271625 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     classifier.0._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=11.6545 calibrator=MaxCalibrator scale=1.0 quant)
# I0328 23:26:29.271768 140449214740288 calibrate.py:131] classifier.0._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=11.6545 calibrator=MaxCalibrator scale=1.0 quant)
# W0328 23:26:29.271936 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([1024, 1]).
# INFO     classifier.0._weight_quantizer          : TensorQuantizer(8bit fake axis=0 amax=[0.0158, 0.4703](1024) calibrator=MaxCalibrator scale=1.0 quant)
# I0328 23:26:29.272221 140449214740288 calibrate.py:131] classifier.0._weight_quantizer          : TensorQuantizer(8bit fake axis=0 amax=[0.0158, 0.4703](1024) calibrator=MaxCalibrator scale=1.0 quant)
# W0328 23:26:29.272616 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     classifier.2._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=38.3167 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.272804 140449214740288 calibrate.py:131] classifier.2._input_quantizer           : TensorQuantizer(8bit fake per-tensor amax=38.3167 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.273202 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     classifier.2._weight_quantizer          : TensorQuantizer(8bit fake per-tensor amax=0.1175 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.273392 140449214740288 calibrate.py:131] classifier.2._weight_quantizer          : TensorQuantizer(8bit fake per-tensor amax=0.1175 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.273818 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     last_layer._input_quantizer             : TensorQuantizer(8bit fake per-tensor amax=19.2420 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.274000 140449214740288 calibrate.py:131] last_layer._input_quantizer             : TensorQuantizer(8bit fake per-tensor amax=19.2420 calibrator=HistogramCalibrator scale=1.0 quant)
# W0328 23:26:29.274388 140449214740288 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     last_layer._weight_quantizer            : TensorQuantizer(8bit fake per-tensor amax=0.1626 calibrator=HistogramCalibrator scale=1.0 quant)
# I0328 23:26:29.274579 140449214740288 calibrate.py:131] last_layer._weight_quantizer            : TensorQuantizer(8bit fake per-tensor amax=0.1626 calibrator=HistogramCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.9...
# I0328 23:26:29.275199 140449214740288 calibrate.py:105] Performing post calibration analysis for calibrator percentile_99.9...
# INFO     Starting transformation analysis on vgg7
# I0328 23:26:29.275390 140449214740288 runtime_analysis.py:357] Starting transformation analysis on vgg7
# INFO
# Results vgg7:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# | Average Validation Accuracy  |   0.92097   |
# |      Average Precision       |   0.91959   |
# |        Average Recall        |   0.91991   |
# |       Average F1 Score       |   0.91957   |
# |         Average Loss         |   0.23991   |
# |       Average Latency        |  18.132 ms  |
# |   Average GPU Power Usage    |  57.867 W   |
# | Inference Energy Consumption | 0.29145 mWh |
# +------------------------------+-------------+
# I0328 23:26:40.146152 140449214740288 runtime_analysis.py:521]
# Results vgg7:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# | Average Validation Accuracy  |   0.92097   |
# |      Average Precision       |   0.91959   |
# |        Average Recall        |   0.91991   |
# |       Average F1 Score       |   0.91957   |
# |         Average Loss         |   0.23991   |
# |       Average Latency        |  18.132 ms  |
# |   Average GPU Power Usage    |  57.867 W   |
# | Inference Energy Consumption | 0.29145 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/mase_graph/version_51/model.json
# I0328 23:26:40.148627 140449214740288 runtime_analysis.py:143] Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/mase_graph/version_51/model.json
# INFO     Post calibration analysis complete.
# I0328 23:26:40.148960 140449214740288 calibrate.py:118] Post calibration analysis complete.
# INFO     Succeeded in calibrating the model in PyTorch!
# I0328 23:26:40.149318 140449214740288 calibrate.py:213] Succeeded in calibrating the model in PyTorch!
# WARNING  Fine tuning is disabled in the config. Skipping QAT fine tuning.
# W0328 23:26:40.155524 140449214740288 fine_tune.py:92] Fine tuning is disabled in the config. Skipping QAT fine tuning.
# INFO     Converting PyTorch model to ONNX...
# I0328 23:26:40.159881 140449214740288 quantize.py:209] Converting PyTorch model to ONNX...
# /root/anaconda3/envs/mase/lib/python3.11/site-packages/pytorch_quantization/tensor_quant.py:363: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_amax < 0:
# /root/anaconda3/envs/mase/lib/python3.11/site-packages/pytorch_quantization/tensor_quant.py:366: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   max_bound = torch.tensor((2.0**(num_bits - 1 + int(unsigned))) - 1.0, device=amax.device)
# /root/anaconda3/envs/mase/lib/python3.11/site-packages/pytorch_quantization/tensor_quant.py:376: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_amax <= epsilon:  # Treat amax smaller than minimum representable of fp16 0
# /root/anaconda3/envs/mase/lib/python3.11/site-packages/pytorch_quantization/tensor_quant.py:382: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_amax <= epsilon:
# INFO     ONNX Conversion Complete. Stored ONNX model to /root/mase/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/2024-03-28/version_43/model.onnx
# I0328 23:26:48.207860 140449214740288 quantize.py:239] ONNX Conversion Complete. Stored ONNX model to /root/mase/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/2024-03-28/version_43/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# I0328 23:26:48.210374 140449214740288 quantize.py:102] Converting PyTorch model to TensorRT...
# [03/28/2024-23:26:55] [TRT] [W] onnx2trt_utils.cpp:374: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# INFO     TensorRT Conversion Complete. Stored trt model to /root/mase/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/2024-03-28/version_40/model.trt
# I0328 23:06:32.223787 139939454809920 quantize.py:202] TensorRT Conversion Complete. Stored trt model to /root/mase/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/2024-03-28/version_40/model.trt
# INFO     TensorRT Model Summary Exported to /root/mase/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/2024-03-28/version_41/model.json
# I0328 23:06:32.581682 139939454809920 quantize.py:259] TensorRT Model Summary Exported to /root/mase/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/2024-03-28/version_41/model.json
# INFO     Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/mase_graph/version_46/model.json
# I0328 23:06:47.114224 139939454809920 runtime_analysis.py:143] Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/mase_graph/version_46/model.json
# INFO     Starting transformation analysis on vgg7-trt_quantized
# I0328 23:06:47.208054 139939454809920 runtime_analysis.py:357] Starting transformation analysis on vgg7-trt_quantized
# INFO
# Results vgg7-trt_quantized:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# | Average Validation Accuracy  |   0.91823   |
# |      Average Precision       |   0.9121    |
# |        Average Recall        |   0.90467   |
# |       Average F1 Score       |   0.92419   |
# |         Average Loss         |   0.24202   |
# |       Average Latency        |  8.2307 ms  |
# |   Average GPU Power Usage    |  55.687 W   |
# | Inference Energy Consumption | 0.12102 mWh |
# +------------------------------+-------------+
# I0328 23:07:00.676242 139939454809920 runtime_analysis.py:521]
# Results vgg7-trt_quantized:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# | Average Validation Accuracy  |   0.91823   |
# |      Average Precision       |   0.9121    |
# |        Average Recall        |   0.90467   |
# |       Average F1 Score       |   0.92419   |
# |         Average Loss         |   0.24202   |
# |       Average Latency        |  8.2307 ms  |
# |   Average GPU Power Usage    |  55.687 W   |
# | Inference Energy Consumption |  0.12102 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/tensorrt/version_8/model.json
# I0328 23:07:00.677799 139939454809920 runtime_analysis.py:143] Runtime analysis results saved to /root/mase_output/tensorrt/quantization/vgg7_cls_cifar10_2024-03-28/tensorrt/version_8/model.json

# %% [markdown]
# In this case, we can see through the quantized summary that one convolutional layer (feature_layers_1) has not been quantized as its precision will be configured to 'fp16' in the tensorrt engine conversion stage whilst the remaining convolutional and linear layers have been quantized.
