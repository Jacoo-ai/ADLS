# %% [markdown]
# ### ADLS Proj: TensorRT with MASE for Multiple Precision Inference
#
# This notebook demonstrates the integration of TensorRT passes into MASE as part of the MASERT framework.
#
# Currently, our experiments are conducted on RTX 4060 and RTX 3070 GPUs, as our request for A100 access is still pending.
#
# ### Objective
# Our goal is to plot trade-off curves that analyze the relationship between different variables, including:
# - **GPU Type** (e.g., RTX 4060, RTX 3070, and A100 when available)
# - **Dataset** (e.g., CIFAR-10)
# - **Model Type** (e.g., ResNet18, ResNet50, VGG, AlexNet ...)
# - **Precision vs. Runtime Trade-off** (FP32, FP16, INT8)
#
# At this stage, we have successfully implemented inference using multiple models, such as **ResNet18 and ResNet50**, on the **CIFAR-10 dataset**. Further experiments will explore the precision-runtime trade-off across different GPU architectures.

# %% [markdown]
# ### Training the Model for Quantization Experiments
#
# In this section, we train an original model of a target model type. The trained model will later serve as a baseline for different precision quantization experiments, including FP32, FP16, and INT8. This process helps in evaluating the trade-offs between model accuracy and runtime efficiency across different GPU architectures.
#
# #### Running the Training Script
#
# To train the model, execute the following command:
#
# ```bash
# !python3 ./ch train --config /workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_INT8_quantization_by_type.toml

# %%
# !python3 ./ch train --config /workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_INT8_quantization_by_type.toml
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0311 00:15:51.512130 140276942296128 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | Name                    |         Default          | Config. File | Manual Override |        Effective         |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | task                    |      classification      |     cls      |                 |           cls            |
# | load_name               |           None           |              |                 |           None           |
# | load_type               |            mz            |              |                 |            mz            |
# | batch_size              |           128            |      64      |                 |            64            |
# | to_debug                |          False           |              |                 |          False           |
# | log_level               |           info           |              |                 |           info           |
# | report_to               |       tensorboard        |              |                 |       tensorboard        |
# | seed                    |            0             |              |                 |            0             |
# | quant_config            |           None           |              |                 |           None           |
# | training_optimizer      |           adam           |              |                 |           adam           |
# | trainer_precision       |         16-mixed         |              |                 |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                 |          0.001           |
# | weight_decay            |            0             |              |                 |            0             |
# | max_epochs              |            20            |      10      |                 |            10            |
# | max_steps               |            -1            |              |                 |            -1            |
# | accumulate_grad_batches |            1             |              |                 |            1             |
# | log_every_n_steps       |            50            |              |                 |            50            |
# | num_workers             |            20            |              |                 |            20            |
# | num_devices             |            1             |              |                 |            1             |
# | num_nodes               |            1             |              |                 |            1             |
# | accelerator             |           auto           |     gpu      |                 |           gpu            |
# | strategy                |           auto           |              |                 |           auto           |
# | is_to_auto_requeue      |          False           |              |                 |          False           |
# | github_ci               |          False           |              |                 |          False           |
# | disable_dataset_cache   |          False           |              |                 |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                 |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                 |           100            |
# | is_pretrained           |          False           |              |                 |          False           |
# | max_token_len           |           512            |              |                 |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                 | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                 |         e_output         |
# | project                 |           None           |              |                 |           None           |
# | model                   |           None           |   resnet18   |                 |         resnet18         |
# | dataset                 |           None           |   cifar10    |                 |         cifar10          |
# | t_max                   |            20            |              |                 |            20            |
# | eta_min                 |          1e-06           |              |                 |          1e-06           |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-11
# INFO     Training model 'resnet18'...
# INFO     ##### WEIGHT DECAY ##### 0
# I0311 00:15:51.711618 140276942296128 rank_zero.py:63] Using 16bit Automatic Mixed Precision (AMP)
# I0311 00:15:51.718478 140276942296128 rank_zero.py:63] GPU available: True (cuda), used: True
# I0311 00:15:51.718928 140276942296128 rank_zero.py:63] TPU available: False, using: 0 TPU cores
# I0311 00:15:51.718978 140276942296128 rank_zero.py:63] HPU available: False, using: 0 HPUs
# I0311 00:15:54.418565 140276942296128 cuda.py:61] LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# I0311 00:15:54.708575 140276942296128 model_summary.py:104]
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | ResNet             | 11.2 M | train
# 1 | loss_fn   | CrossEntropyLoss   | 0      | train
# 2 | acc_train | MulticlassAccuracy | 0      | train
# 3 | loss_val  | MeanMetric         | 0      | train
# 4 | loss_test | MeanMetric         | 0      | train
# ---------------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.727    Total estimated model params size (MB)
# 72        Modules in train mode
# 0         Modules in eval mode
# Epoch 0:  53%|▌| 411/782 [00:11<00:10, 35.12it/s, v_num=0, train_acc_step=0.234]I0311 00:16:07.596064 140276942296128 rank_zero.py:63]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ^C

# %% [markdown]
# ## Explore Sparsity

# %%
FP16_SPARSITY_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/proj/resnet18_FP16_spar.toml"
RES_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {FP16_SPARSITY_BY_TYPE_TOML} --load {RES_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0319 01:41:30.468708 140167305331776 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+----------------------+--------------------------+--------------------------+
# | Name                    |         Default          |     Config. File     |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+----------------------+--------------------------+--------------------------+
# | task                    |      classification      |         cls          |                          |           cls            |
# | load_name               |           None           |                      | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |                      | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |                      | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |                      | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |                      |            pt            |            pt            |
# | load_type               |            mz            |                      |            pl            |            pl            |
# | batch_size              |           128            | [8, 16, 32, 64, 128] |                          |   [8, 16, 32, 64, 128]   |
# | to_debug                |          False           |                      |                          |          False           |
# | log_level               |           info           |                      |                          |           info           |
# | report_to               |       tensorboard        |                      |                          |       tensorboard        |
# | seed                    |            0             |                      |                          |            0             |
# | quant_config            |           None           |                      |                          |           None           |
# | training_optimizer      |           adam           |                      |                          |           adam           |
# | trainer_precision       |         16-mixed         |                      |                          |         16-mixed         |
# | learning_rate           |          1e-05           |        0.001         |                          |          0.001           |
# | weight_decay            |            0             |                      |                          |            0             |
# | max_epochs              |            20            |          10          |                          |            10            |
# | max_steps               |            -1            |                      |                          |            -1            |
# | accumulate_grad_batches |            1             |                      |                          |            1             |
# | log_every_n_steps       |            50            |                      |                          |            50            |
# | num_workers             |            20            |                      |                          |            20            |
# | num_devices             |            1             |                      |                          |            1             |
# | num_nodes               |            1             |                      |                          |            1             |
# | accelerator             |           auto           |         gpu          |                          |           gpu            |
# | strategy                |           auto           |                      |                          |           auto           |
# | is_to_auto_requeue      |          False           |                      |                          |          False           |
# | github_ci               |          False           |                      |                          |          False           |
# | disable_dataset_cache   |          False           |                      |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |                      |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |                      |                          |           100            |
# | is_pretrained           |          False           |                      |                          |          False           |
# | max_token_len           |           512            |                      |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |                      |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |                      |                          |         e_output         |
# | project                 |           None           |                      |                          |           None           |
# | model                   |           None           |       resnet18       |                          |         resnet18         |
# | dataset                 |           None           |       cifar10        |                          |         cifar10          |
# | t_max                   |            20            |                      |                          |            20            |
# | eta_min                 |          1e-06           |                      |                          |          1e-06           |
# +-------------------------+--------------------------+----------------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-19
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# INFO     (transnew) Using graph style transform on resnet18 ...
# INFO     === Start passes for batch_size=8 ===
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# INFO     >> runtime_analysis_ori pass ...
# using safe deepcopy
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.53327    |
# |      Average Precision       |   0.64654    |
# |        Average Recall        |   0.64912    |
# |       Average F1 Score       |   0.64651    |
# |         Average Loss         |    1.026     |
# |       Average Latency        |  5.9115 ms   |
# |   Average GPU Power Usage    |   11.894 W   |
# | Inference Energy Consumption | 0.019531 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/mase_graph/version_21/model.json
# INFO     >> tensorrt_fp16 pass ...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_50/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# default_precision: fp16
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_51/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_52/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:42:07] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.62759    |
# |      Average Precision       |    0.72678    |
# |        Average Recall        |    0.71944    |
# |       Average F1 Score       |    0.71912    |
# |         Average Loss         |    0.80693    |
# |       Average Latency        |  0.60001 ms   |
# |   Average GPU Power Usage    |   8.7055 W    |
# | Inference Energy Consumption | 0.0014509 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_11/model.json
# INFO     >> sparsity_fp16 pass ...
# INFO     Using batch_size=8 for sparsity pass
# INFO     Applying 2:4 structured sparsity to PyTorch weights ...
# INFO     2:4 structured sparsity done.
# INFO     Exporting model to ONNX for FP16 + SPARSE (batch_size=8)
# INFO     ONNX exported => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_53/model.onnx
# INFO     Building TensorRT engine with FP16 + SPARSE_WEIGHTS (batch_size=8)
# TensorRT Input Shape:  (8, 3, 32, 32)
# TensorRT Optimized Input Shape: [(8, 3, 32, 32), (8, 3, 32, 32), (8, 3, 32, 32)]
# INFO     Sparse + FP16 TensorRT engine built => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_54/model.trt
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:42:33] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.45591    |
# |      Average Precision       |    0.6829     |
# |        Average Recall        |    0.53838    |
# |       Average F1 Score       |    0.52481    |
# |         Average Loss         |    1.3923     |
# |       Average Latency        |  0.55437 ms   |
# |   Average GPU Power Usage    |   9.3351 W    |
# | Inference Energy Consumption | 0.0014375 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_12/model.json
# INFO     === Finished passes for batch_size=8 ===
#
# INFO     === Start passes for batch_size=16 ===
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# INFO     >> runtime_analysis_ori pass ...
# using safe deepcopy
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.63839    |
# |      Average Precision       |   0.69645    |
# |        Average Recall        |   0.69868    |
# |       Average F1 Score       |   0.69676    |
# |         Average Loss         |   0.88776    |
# |       Average Latency        |  5.1485 ms   |
# |   Average GPU Power Usage    |   12.577 W   |
# | Inference Energy Consumption | 0.017987 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/mase_graph/version_22/model.json
# INFO     >> tensorrt_fp16 pass ...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_55/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# default_precision: fp16
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_56/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_57/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:43:02] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |     0.675     |
# |      Average Precision       |    0.7321     |
# |        Average Recall        |    0.72929    |
# |       Average F1 Score       |    0.72824    |
# |         Average Loss         |    0.78645    |
# |       Average Latency        |  0.57991 ms   |
# |   Average GPU Power Usage    |   9.9692 W    |
# | Inference Energy Consumption | 0.0016059 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_13/model.json
# INFO     >> sparsity_fp16 pass ...
# INFO     Using batch_size=16 for sparsity pass
# INFO     Applying 2:4 structured sparsity to PyTorch weights ...
# INFO     2:4 structured sparsity done.
# INFO     Exporting model to ONNX for FP16 + SPARSE (batch_size=16)
# INFO     ONNX exported => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_58/model.onnx
# INFO     Building TensorRT engine with FP16 + SPARSE_WEIGHTS (batch_size=16)
# TensorRT Input Shape:  (16, 3, 32, 32)
# TensorRT Optimized Input Shape: [(16, 3, 32, 32), (16, 3, 32, 32), (16, 3, 32, 32)]
# INFO     Sparse + FP16 TensorRT engine built => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_59/model.trt
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:43:28] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.45489    |
# |      Average Precision       |    0.67223    |
# |        Average Recall        |    0.49167    |
# |       Average F1 Score       |    0.4734     |
# |         Average Loss         |    1.4755     |
# |       Average Latency        |  0.57591 ms   |
# |   Average GPU Power Usage    |   9.7974 W    |
# | Inference Energy Consumption | 0.0015673 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_14/model.json
# INFO     === Finished passes for batch_size=16 ===
#
# INFO     === Start passes for batch_size=32 ===
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# INFO     >> runtime_analysis_ori pass ...
# using safe deepcopy
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.70809    |
# |      Average Precision       |   0.70874    |
# |        Average Recall        |   0.71192    |
# |       Average F1 Score       |   0.70968    |
# |         Average Loss         |    0.8365    |
# |       Average Latency        |  5.8677 ms   |
# |   Average GPU Power Usage    |   14.863 W   |
# | Inference Energy Consumption | 0.024226 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/mase_graph/version_23/model.json
# INFO     >> tensorrt_fp16 pass ...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_60/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# default_precision: fp16
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_61/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_62/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:43:54] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.71685    |
# |      Average Precision       |    0.73635    |
# |        Average Recall        |    0.73422    |
# |       Average F1 Score       |    0.7338     |
# |         Average Loss         |    0.77976    |
# |       Average Latency        |  0.57844 ms   |
# |   Average GPU Power Usage    |   10.405 W    |
# | Inference Energy Consumption | 0.0016719 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_15/model.json
# INFO     >> sparsity_fp16 pass ...
# INFO     Using batch_size=32 for sparsity pass
# INFO     Applying 2:4 structured sparsity to PyTorch weights ...
# INFO     2:4 structured sparsity done.
# INFO     Exporting model to ONNX for FP16 + SPARSE (batch_size=32)
# INFO     ONNX exported => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_63/model.onnx
# INFO     Building TensorRT engine with FP16 + SPARSE_WEIGHTS (batch_size=32)
# TensorRT Input Shape:  (32, 3, 32, 32)
# TensorRT Optimized Input Shape: [(32, 3, 32, 32), (32, 3, 32, 32), (32, 3, 32, 32)]
# INFO     Sparse + FP16 TensorRT engine built => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_64/model.trt
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:44:20] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.49246    |
# |      Average Precision       |    0.67232    |
# |        Average Recall        |    0.50204    |
# |       Average F1 Score       |    0.49103    |
# |         Average Loss         |    1.4517     |
# |       Average Latency        |  0.59578 ms   |
# |   Average GPU Power Usage    |   9.4811 W    |
# | Inference Energy Consumption | 0.0015691 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_16/model.json
# INFO     === Finished passes for batch_size=32 ===
#
# INFO     === Start passes for batch_size=64 ===
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# INFO     >> runtime_analysis_ori pass ...
# using safe deepcopy
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72733    |
# |      Average Precision       |   0.71774    |
# |        Average Recall        |    0.7211    |
# |       Average F1 Score       |   0.71844    |
# |         Average Loss         |   0.81241    |
# |       Average Latency        |  8.1603 ms   |
# |   Average GPU Power Usage    |   11.239 W   |
# | Inference Energy Consumption | 0.025476 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/mase_graph/version_24/model.json
# INFO     >> tensorrt_fp16 pass ...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_65/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# default_precision: fp16
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_66/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_67/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:44:45] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.73282    |
# |      Average Precision       |    0.73594    |
# |        Average Recall        |    0.73624    |
# |       Average F1 Score       |    0.7351     |
# |         Average Loss         |    0.77958    |
# |       Average Latency        |  0.62346 ms   |
# |   Average GPU Power Usage    |   10.433 W    |
# | Inference Energy Consumption | 0.0018069 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_17/model.json
# INFO     >> sparsity_fp16 pass ...
# INFO     Using batch_size=64 for sparsity pass
# INFO     Applying 2:4 structured sparsity to PyTorch weights ...
# INFO     2:4 structured sparsity done.
# INFO     Exporting model to ONNX for FP16 + SPARSE (batch_size=64)
# INFO     ONNX exported => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_68/model.onnx
# INFO     Building TensorRT engine with FP16 + SPARSE_WEIGHTS (batch_size=64)
# TensorRT Input Shape:  (64, 3, 32, 32)
# TensorRT Optimized Input Shape: [(64, 3, 32, 32), (64, 3, 32, 32), (64, 3, 32, 32)]
# INFO     Sparse + FP16 TensorRT engine built => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_69/model.trt
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:45:10] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.51205    |
# |      Average Precision       |    0.66844    |
# |        Average Recall        |    0.51262    |
# |       Average F1 Score       |    0.50206    |
# |         Average Loss         |    1.4257     |
# |       Average Latency        |  0.59702 ms   |
# |   Average GPU Power Usage    |   10.694 W    |
# | Inference Energy Consumption | 0.0017735 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_18/model.json
# INFO     === Finished passes for batch_size=64 ===
#
# INFO     === Start passes for batch_size=128 ===
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# INFO     >> runtime_analysis_ori pass ...
# using safe deepcopy
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.73052    |
# |      Average Precision       |   0.72403    |
# |        Average Recall        |   0.72725    |
# |       Average F1 Score       |   0.72451    |
# |         Average Loss         |   0.80109    |
# |       Average Latency        |  8.6898 ms   |
# |   Average GPU Power Usage    |   9.7011 W   |
# | Inference Energy Consumption | 0.023417 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/mase_graph/version_25/model.json
# INFO     >> tensorrt_fp16 pass ...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_70/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# default_precision: fp16
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_71/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_72/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:45:33] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.73229    |
# |      Average Precision       |    0.73298    |
# |        Average Recall        |    0.73491    |
# |       Average F1 Score       |    0.73307    |
# |         Average Loss         |    0.7835     |
# |       Average Latency        |  0.86373 ms   |
# |   Average GPU Power Usage    |   16.514 W    |
# | Inference Energy Consumption | 0.0039621 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_19/model.json
# INFO     >> sparsity_fp16 pass ...
# INFO     Using batch_size=128 for sparsity pass
# INFO     Applying 2:4 structured sparsity to PyTorch weights ...
# INFO     2:4 structured sparsity done.
# INFO     Exporting model to ONNX for FP16 + SPARSE (batch_size=128)
# INFO     ONNX exported => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_73/model.onnx
# INFO     Building TensorRT engine with FP16 + SPARSE_WEIGHTS (batch_size=128)
# TensorRT Input Shape:  (128, 3, 32, 32)
# TensorRT Optimized Input Shape: [(128, 3, 32, 32), (128, 3, 32, 32), (128, 3, 32, 32)]
# INFO     Sparse + FP16 TensorRT engine built => /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/2025-03-19/version_74/model.trt
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/19/2025-01:45:58] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.52231    |
# |      Average Precision       |    0.66708    |
# |        Average Recall        |    0.52451    |
# |       Average F1 Score       |    0.5152     |
# |         Average Loss         |    1.4068     |
# |       Average Latency        |  0.81243 ms   |
# |   Average GPU Power Usage    |   11.204 W    |
# | Inference Energy Consumption | 0.0025285 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-19/tensorrt/version_20/model.json
# INFO     === Finished passes for batch_size=128 ===
#
# INFO     Plot saved to: /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-19/software/transform/multi_bs_curves.png
# INFO     CSV saved to: /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-19/software/transform/multi_bs_results.csv
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-19/software/transform/transformed_ckpt
# INFO     transform_graph complete.
# INFO     Transformation is completed
