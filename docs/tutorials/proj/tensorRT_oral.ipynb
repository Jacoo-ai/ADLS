# %% [markdown]
# ### ADLS Proj: TensorRT with MASE for Multiple Precision Inference
#
# This notebook demonstrates the integration of TensorRT passes into MASE as part of the MASERT framework.
#
# Currently, our experiments are conducted on RTX 4060 and RTX 3070 GPUs, as our request for A100 access is still pending.
#
# ### Objective
# Our goal is to plot trade-off curves that analyze the relationship between different variables, including:
# - **GPU Type** (e.g., RTX 4060, RTX 3070, and A100 when available)
# - **Dataset** (e.g., CIFAR-10)
# - **Model Type** (e.g., ResNet18, ResNet50, VGG, AlexNet ...)
# - **Precision vs. Runtime Trade-off** (FP32, FP16, INT8)
#
# At this stage, we have successfully implemented inference using multiple models, such as **ResNet18 and ResNet50**, on the **CIFAR-10 dataset**. Further experiments will explore the precision-runtime trade-off across different GPU architectures.

# %% [markdown]
# ### Training the Model for Quantization Experiments
#
# In this section, we train an original model of a target model type. The trained model will later serve as a baseline for different precision quantization experiments, including FP32, FP16, and INT8. This process helps in evaluating the trade-offs between model accuracy and runtime efficiency across different GPU architectures.
#
# #### Running the Training Script
#
# To train the model, execute the following command:
#
# ```bash
# !python3 ./ch train --config /workspace/ADLS_Proj/docs/tutorials/tensorrt/resnet18_INT8_quantization_by_type.toml

# %%
# !python3 ./ch train --config /workspace/ADLS_Proj/docs/tutorials/proj/resnet18_INT8_quant.toml
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0311 00:15:51.512130 140276942296128 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | Name                    |         Default          | Config. File | Manual Override |        Effective         |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | task                    |      classification      |     cls      |                 |           cls            |
# | load_name               |           None           |              |                 |           None           |
# | load_type               |            mz            |              |                 |            mz            |
# | batch_size              |           128            |      64      |                 |            64            |
# | to_debug                |          False           |              |                 |          False           |
# | log_level               |           info           |              |                 |           info           |
# | report_to               |       tensorboard        |              |                 |       tensorboard        |
# | seed                    |            0             |              |                 |            0             |
# | quant_config            |           None           |              |                 |           None           |
# | training_optimizer      |           adam           |              |                 |           adam           |
# | trainer_precision       |         16-mixed         |              |                 |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                 |          0.001           |
# | weight_decay            |            0             |              |                 |            0             |
# | max_epochs              |            20            |      10      |                 |            10            |
# | max_steps               |            -1            |              |                 |            -1            |
# | accumulate_grad_batches |            1             |              |                 |            1             |
# | log_every_n_steps       |            50            |              |                 |            50            |
# | num_workers             |            20            |              |                 |            20            |
# | num_devices             |            1             |              |                 |            1             |
# | num_nodes               |            1             |              |                 |            1             |
# | accelerator             |           auto           |     gpu      |                 |           gpu            |
# | strategy                |           auto           |              |                 |           auto           |
# | is_to_auto_requeue      |          False           |              |                 |          False           |
# | github_ci               |          False           |              |                 |          False           |
# | disable_dataset_cache   |          False           |              |                 |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                 |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                 |           100            |
# | is_pretrained           |          False           |              |                 |          False           |
# | max_token_len           |           512            |              |                 |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                 | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                 |         e_output         |
# | project                 |           None           |              |                 |           None           |
# | model                   |           None           |   resnet18   |                 |         resnet18         |
# | dataset                 |           None           |   cifar10    |                 |         cifar10          |
# | t_max                   |            20            |              |                 |            20            |
# | eta_min                 |          1e-06           |              |                 |          1e-06           |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-11
# INFO     Training model 'resnet18'...
# INFO     ##### WEIGHT DECAY ##### 0
# I0311 00:15:51.711618 140276942296128 rank_zero.py:63] Using 16bit Automatic Mixed Precision (AMP)
# I0311 00:15:51.718478 140276942296128 rank_zero.py:63] GPU available: True (cuda), used: True
# I0311 00:15:51.718928 140276942296128 rank_zero.py:63] TPU available: False, using: 0 TPU cores
# I0311 00:15:51.718978 140276942296128 rank_zero.py:63] HPU available: False, using: 0 HPUs
# I0311 00:15:54.418565 140276942296128 cuda.py:61] LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# I0311 00:15:54.708575 140276942296128 model_summary.py:104]
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | ResNet             | 11.2 M | train
# 1 | loss_fn   | CrossEntropyLoss   | 0      | train
# 2 | acc_train | MulticlassAccuracy | 0      | train
# 3 | loss_val  | MeanMetric         | 0      | train
# 4 | loss_test | MeanMetric         | 0      | train
# ---------------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.727    Total estimated model params size (MB)
# 72        Modules in train mode
# 0         Modules in eval mode
# Epoch 0:  53%|▌| 411/782 [00:11<00:10, 35.12it/s, v_num=0, train_acc_step=0.234]I0311 00:16:07.596064 140276942296128 rank_zero.py:63]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ^C

# %% [markdown]
# input: Model:Resnet18 Restnet50 VGG
#
# Variable: Precision: INT8 FP16 FP32 (Original) | batch size
#
# Output: Original INT8 FP16 FP32 (Acc, Runtime)(Model, batch size)

# %%
MUL_PRECISION_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/proj/resnet18_INT8_quant.toml"
RES_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {MUL_PRECISION_BY_TYPE_TOML} --load {RES_CHECKPOINT_PATH} --load-type pl

# %% [markdown]
# ### INT8 Quantization with TensorRT
#
# This section explains the process of **INT8 quantization** using TensorRT within the MASE framework. The key steps include **fake quantization, calibration, fine-tuning, and generating a TensorRT engine**.
#
# ### Code Execution Flow
#
# 1. **Apply TensorRT Passes**
#    - **Fake Quantization**: Inserts quantization simulation operations.
#    - **Summarization**: Displays which layers were quantized.
#    - **Calibration**: Uses calibration algorithms (e.g., histogram-based) to determine optimal quantization parameters.
#    - **Fine-Tuning**: Adjusts parameters to recover accuracy loss after quantization.
#
# 2. **Generate the TensorRT Engine**
#    - Calls `tensorrt_engine_interface_pass` to convert the optimized graph into a **TensorRT engine**.
#
# 3. **Benchmarking & Performance Analysis**
#    - Runs inference tests with warm-up and batch evaluation to measure efficiency.

# %%
RES_INT8_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/proj/resnet18_INT8_quant.toml"
RES_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {RES_INT8_BY_TYPE_TOML} --load {RES_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0316 23:33:16.033470 139949971272768 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-16
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile', 'mse', 'entropy'], 'percentiles': [99.0, 99.9, 99.99], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': True}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     Running minimal runtime analysis on original graph (just 1 batch) ...
# INFO     Before analyzing original graph: pass_args = {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile', 'mse', 'entropy'], 'percentiles': [99.0, 99.9, 99.99], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': True}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}, 'task': 'cls', 'dataset': 'cifar10', 'batch_size': 64, 'model': 'resnet18', 'data_module': <chop.dataset.MaseDataModule object at 0x7f46783a6790>, 'accelerator': 'cuda', 'num_GPU_warmup_batches': 0, 'num_batches': 1, 'test': True}
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.68146    |
# |      Average Precision       |   0.72305    |
# |        Average Recall        |   0.70312    |
# |       Average F1 Score       |    0.7063    |
# |         Average Loss         |   0.88661    |
# |       Average Latency        |  9.1563 ms   |
# |   Average GPU Power Usage    |   12.336 W   |
# | Inference Energy Consumption | 0.031376 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_92/model.json
# INFO     Applying fake quantization to PyTorch model...
# op is placeholder
# placeholder not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is max_pool2d
# max_pool2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is adaptive_avg_pool2d
# adaptive_avg_pool2d not in QUANTIZEABLE_OP
# op is flatten
# flatten not in QUANTIZEABLE_OP
# op is linear
# node.op == call_module
# op is output
# output not in QUANTIZEABLE_OP
# INFO     Fake quantization applied to PyTorch model.
# INFO     Quantized graph histogram:
# INFO
# | Original type     | OP                  |   Total |   Changed |   Unchanged |
# |-------------------+---------------------+---------+-----------+-------------|
# | AdaptiveAvgPool2d | adaptive_avg_pool2d |       1 |         0 |           1 |
# | BatchNorm2d       | batch_norm2d        |      20 |         0 |          20 |
# | MaxPool2d         | max_pool2d          |       1 |         0 |           1 |
# | QuantConv2d       | conv2d              |      20 |         0 |          20 |
# | QuantLinear       | linear              |       1 |         0 |           1 |
# | ReLU              | relu                |      17 |         0 |          17 |
# | add               | add                 |       8 |         0 |           8 |
# | flatten           | flatten             |       1 |         0 |           1 |
# | output            | output              |       1 |         0 |           1 |
# | x                 | placeholder         |       1 |         0 |           1 |
# INFO     Starting calibration of the model in PyTorch...
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.374635 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.374905 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375022 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375117 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375214 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375304 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375401 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375502 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375596 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375684 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375777 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375866 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.375959 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376046 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376138 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376226 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376351 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376449 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376544 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376631 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376723 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.376934 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377039 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377126 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377218 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377311 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377403 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377496 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377590 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377676 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377769 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377855 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.377939 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378027 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378117 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378202 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378294 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378367 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378456 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378540 139949971272768 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378637 139949971272768 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0316 23:33:28.378722 139949971272768 tensor_quantizer.py:174] Disable MaxCalibrator
# W0316 23:33:28.378963 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W0316 23:33:28.379018 139949971272768 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6224 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.379268 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1400 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.379453 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2058 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.379612 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2111 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.379772 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1079 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.379925 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1980 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.380090 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.8223 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.380250 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1957 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.380419 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1361 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.380581 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1970 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.380751 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.4339 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.380904 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1583 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.381063 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2583 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.381209 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1586 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.381362 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.4339 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.381511 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3493 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.381663 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5862 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.381811 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.382134 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2681 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.382292 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1517 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.382451 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.5355 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.382599 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1277 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.382751 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.6591 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.382896 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1132 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.383047 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=4.5355 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.383193 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2536 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.383353 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.3890 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.383574 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.383742 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2634 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384056 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0944 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384229 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.2509 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384377 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0710 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384526 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5516 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384670 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0598 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384847 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.2509 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.384998 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.1907 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.385150 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.7655 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.385288 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.385429 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.8474 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.385566 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:28.385680 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.7439 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 23:33:28.386364 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.0...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72647    |
# |      Average Precision       |   0.71544    |
# |        Average Recall        |   0.71927    |
# |       Average F1 Score       |   0.71627    |
# |         Average Loss         |   0.81653    |
# |       Average Latency        |   28.48 ms   |
# |   Average GPU Power Usage    |   9.9762 W   |
# | Inference Energy Consumption | 0.078923 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_93/model.json
# INFO     Post calibration analysis complete.
# W0316 23:33:34.669170 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6391 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.670367 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1815 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.670709 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.4239 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.670995 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2904 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.671260 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.2295 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.671504 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2525 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.671758 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.1635 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.672040 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2498 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.672278 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.1502 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.672672 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2537 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.672982 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.9474 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.673335 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.673606 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3220 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.673857 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.674115 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=7.9474 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.674345 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4401 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.674587 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.2313 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.674825 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2007 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.675070 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3806 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.675660 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1949 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.675922 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.8090 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.676162 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1651 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.676598 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.0989 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.676830 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1593 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.677070 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=6.8090 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.677295 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3283 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.677526 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.6025 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.677749 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1263 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.677980 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.5455 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.678203 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1284 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.678431 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.6085 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.678693 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1042 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.678922 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.4767 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.679169 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0840 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.679399 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=8.6085 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.679628 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2463 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.679853 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.5514 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.680091 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0714 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.680317 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.3538 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.680538 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0719 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:34.680737 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.7439 calibrator=MaxCalibrator scale=1.0 quant)
# W0316 23:33:34.680893 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.9...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72817    |
# |      Average Precision       |   0.71891    |
# |        Average Recall        |   0.72206    |
# |       Average F1 Score       |   0.71969    |
# |         Average Loss         |   0.80688    |
# |       Average Latency        |  26.695 ms   |
# |   Average GPU Power Usage    |   10.231 W   |
# | Inference Energy Consumption | 0.075864 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/mase_graph/version_94/model.json
# INFO     Post calibration analysis complete.
# W0316 23:33:40.369793 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=3.0904 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.370489 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.2071 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.370844 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.8670 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.371139 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3663 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.371416 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.3450 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.371681 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2896 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.371962 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=9.6981 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.372231 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2951 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.372495 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1751 calibrator=HistogramCalibrator scale=1.0 quant)
# W0316 23:33:40.372755 139949971272768 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2948 calibrator=HistogramCalibrator scale=1.0 quant)
# ...
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:03<00:00, 43.96it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:03<00:00, 43.98it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:03<00:00, 43.98it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:03<00:00, 43.98it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:03<00:00, 43.97it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:03<00:00, 43.98it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:03<00:00, 43.96it/s]
# Epoch 1: 100%|█| 782/782 [00:30<00:00, 25.29it/s, v_num=21, train_acc_step=0.625
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:04, 35.86it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:03, 39.49it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:03, 43.30it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:03, 44.37it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:03, 44.60it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:03, 44.48it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:03, 44.42it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:03, 44.54it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:03, 44.83it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:03, 45.04it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:03, 44.61it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:03, 44.69it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:03, 44.83it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:03, 44.74it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:03, 44.99it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:03, 44.71it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:03, 44.81it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:03, 43.79it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:03, 44.01it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:03, 43.68it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:03, 43.25it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:03, 41.86it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:03, 41.87it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:03, 41.30it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:03, 41.23it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:03, 41.22it/s]
# Validation DataLoader 0:  17%|██▉              | 27/157 [00:00<00:03, 41.17it/s]
# Validation DataLoader 0:  18%|███              | 28/157 [00:00<00:03, 41.23it/s]
# Validation DataLoader 0:  18%|███▏             | 29/157 [00:00<00:03, 41.35it/s]
# Validation DataLoader 0:  19%|███▏             | 30/157 [00:00<00:03, 41.43it/s]
# Validation DataLoader 0:  20%|███▎             | 31/157 [00:00<00:03, 41.52it/s]
# Validation DataLoader 0:  20%|███▍             | 32/157 [00:00<00:03, 41.39it/s]
# Validation DataLoader 0:  21%|███▌             | 33/157 [00:00<00:02, 41.38it/s]
# Validation DataLoader 0:  22%|███▋             | 34/157 [00:00<00:02, 41.11it/s]
# Validation DataLoader 0:  22%|███▊             | 35/157 [00:00<00:02, 40.88it/s]
# Validation DataLoader 0:  23%|███▉             | 36/157 [00:00<00:02, 40.65it/s]
# Validation DataLoader 0:  24%|████             | 37/157 [00:00<00:02, 40.71it/s]
# Validation DataLoader 0:  24%|████             | 38/157 [00:00<00:02, 40.72it/s]
# Validation DataLoader 0:  25%|████▏            | 39/157 [00:00<00:02, 40.81it/s]
# Validation DataLoader 0:  25%|████▎            | 40/157 [00:00<00:02, 40.79it/s]
# Validation DataLoader 0:  26%|████▍            | 41/157 [00:01<00:02, 40.57it/s]
# Validation DataLoader 0:  27%|████▌            | 42/157 [00:01<00:02, 40.50it/s]
# Validation DataLoader 0:  27%|████▋            | 43/157 [00:01<00:02, 40.44it/s]
# Validation DataLoader 0:  28%|████▊            | 44/157 [00:01<00:02, 40.38it/s]
# Validation DataLoader 0:  29%|████▊            | 45/157 [00:01<00:02, 40.39it/s]
# Validation DataLoader 0:  29%|████▉            | 46/157 [00:01<00:02, 40.45it/s]
# Validation DataLoader 0:  30%|█████            | 47/157 [00:01<00:02, 40.44it/s]
# Validation DataLoader 0:  31%|█████▏           | 48/157 [00:01<00:02, 40.40it/s]
# Validation DataLoader 0:  31%|█████▎           | 49/157 [00:01<00:02, 39.91it/s]
# Validation DataLoader 0:  32%|█████▍           | 50/157 [00:01<00:02, 39.95it/s]
# Validation DataLoader 0:  32%|█████▌           | 51/157 [00:01<00:02, 39.84it/s]
# Validation DataLoader 0:  33%|█████▋           | 52/157 [00:01<00:02, 39.92it/s]
# Validation DataLoader 0:  34%|█████▋           | 53/157 [00:01<00:02, 39.86it/s]
# Validation DataLoader 0:  34%|█████▊           | 54/157 [00:01<00:02, 39.84it/s]
# Validation DataLoader 0:  35%|█████▉           | 55/157 [00:01<00:02, 39.77it/s]
# Validation DataLoader 0:  36%|██████           | 56/157 [00:01<00:02, 39.84it/s]
# Validation DataLoader 0:  36%|██████▏          | 57/157 [00:01<00:02, 39.73it/s]
# Validation DataLoader 0:  37%|██████▎          | 58/157 [00:01<00:02, 39.78it/s]
# Validation DataLoader 0:  38%|██████▍          | 59/157 [00:01<00:02, 39.65it/s]
# Validation DataLoader 0:  38%|██████▍          | 60/157 [00:01<00:02, 39.69it/s]
# Validation DataLoader 0:  39%|██████▌          | 61/157 [00:01<00:02, 39.72it/s]
# Validation DataLoader 0:  39%|██████▋          | 62/157 [00:01<00:02, 39.74it/s]
# Validation DataLoader 0:  40%|██████▊          | 63/157 [00:01<00:02, 39.70it/s]
# Validation DataLoader 0:  41%|██████▉          | 64/157 [00:01<00:02, 39.66it/s]
# Validation DataLoader 0:  41%|███████          | 65/157 [00:01<00:02, 39.65it/s]
# Validation DataLoader 0:  42%|███████▏         | 66/157 [00:01<00:02, 39.73it/s]
# Validation DataLoader 0:  43%|███████▎         | 67/157 [00:01<00:02, 39.70it/s]
# Validation DataLoader 0:  43%|███████▎         | 68/157 [00:01<00:02, 39.71it/s]
# Validation DataLoader 0:  44%|███████▍         | 69/157 [00:01<00:02, 39.69it/s]
# Validation DataLoader 0:  45%|███████▌         | 70/157 [00:01<00:02, 39.62it/s]
# Validation DataLoader 0:  45%|███████▋         | 71/157 [00:01<00:02, 39.63it/s]
# Validation DataLoader 0:  46%|███████▊         | 72/157 [00:01<00:02, 39.67it/s]
# Validation DataLoader 0:  46%|███████▉         | 73/157 [00:01<00:02, 39.48it/s]
# Validation DataLoader 0:  47%|████████         | 74/157 [00:01<00:02, 39.44it/s]
# Validation DataLoader 0:  48%|████████         | 75/157 [00:01<00:02, 39.37it/s]
# Validation DataLoader 0:  48%|████████▏        | 76/157 [00:01<00:02, 39.34it/s]
# Validation DataLoader 0:  49%|████████▎        | 77/157 [00:01<00:02, 39.40it/s]
# Validation DataLoader 0:  50%|████████▍        | 78/157 [00:01<00:02, 39.39it/s]
# Validation DataLoader 0:  50%|████████▌        | 79/157 [00:02<00:01, 39.44it/s]
# Validation DataLoader 0:  51%|████████▋        | 80/157 [00:02<00:01, 39.44it/s]
# Validation DataLoader 0:  52%|████████▊        | 81/157 [00:02<00:01, 39.48it/s]
# Validation DataLoader 0:  52%|████████▉        | 82/157 [00:02<00:01, 39.48it/s]
# Validation DataLoader 0:  53%|████████▉        | 83/157 [00:02<00:01, 39.35it/s]
# Validation DataLoader 0:  54%|█████████        | 84/157 [00:02<00:01, 39.36it/s]
# Validation DataLoader 0:  54%|█████████▏       | 85/157 [00:02<00:01, 39.32it/s]
# Validation DataLoader 0:  55%|█████████▎       | 86/157 [00:02<00:01, 39.30it/s]
# Validation DataLoader 0:  55%|█████████▍       | 87/157 [00:02<00:01, 39.34it/s]
# Validation DataLoader 0:  56%|█████████▌       | 88/157 [00:02<00:01, 39.35it/s]
# Validation DataLoader 0:  57%|█████████▋       | 89/157 [00:02<00:01, 39.38it/s]
# Validation DataLoader 0:  57%|█████████▋       | 90/157 [00:02<00:01, 39.39it/s]
# Validation DataLoader 0:  58%|█████████▊       | 91/157 [00:02<00:01, 39.39it/s]
# Validation DataLoader 0:  59%|█████████▉       | 92/157 [00:02<00:01, 39.18it/s]
# Validation DataLoader 0:  59%|██████████       | 93/157 [00:02<00:01, 39.01it/s]
# Validation DataLoader 0:  60%|██████████▏      | 94/157 [00:02<00:01, 38.99it/s]
# Validation DataLoader 0:  61%|██████████▎      | 95/157 [00:02<00:01, 38.95it/s]
# Validation DataLoader 0:  61%|██████████▍      | 96/157 [00:02<00:01, 38.99it/s]
# Validation DataLoader 0:  62%|██████████▌      | 97/157 [00:02<00:01, 38.91it/s]
# Validation DataLoader 0:  62%|██████████▌      | 98/157 [00:02<00:01, 38.94it/s]
# Validation DataLoader 0:  63%|██████████▋      | 99/157 [00:02<00:01, 38.83it/s]
# Validation DataLoader 0:  64%|██████████▏     | 100/157 [00:02<00:01, 38.84it/s]
# Validation DataLoader 0:  64%|██████████▎     | 101/157 [00:02<00:01, 38.83it/s]
# Validation DataLoader 0:  65%|██████████▍     | 102/157 [00:02<00:01, 38.84it/s]
# Validation DataLoader 0:  66%|██████████▍     | 103/157 [00:02<00:01, 38.65it/s]
# Validation DataLoader 0:  66%|██████████▌     | 104/157 [00:02<00:01, 38.58it/s]
# Validation DataLoader 0:  67%|██████████▋     | 105/157 [00:02<00:01, 38.60it/s]
# Validation DataLoader 0:  68%|██████████▊     | 106/157 [00:02<00:01, 38.58it/s]
# Validation DataLoader 0:  68%|██████████▉     | 107/157 [00:02<00:01, 38.59it/s]
# Validation DataLoader 0:  69%|███████████     | 108/157 [00:02<00:01, 38.58it/s]
# Validation DataLoader 0:  69%|███████████     | 109/157 [00:02<00:01, 38.42it/s]
# Validation DataLoader 0:  70%|███████████▏    | 110/157 [00:02<00:01, 38.44it/s]
# Validation DataLoader 0:  71%|███████████▎    | 111/157 [00:02<00:01, 38.42it/s]
# Validation DataLoader 0:  71%|███████████▍    | 112/157 [00:02<00:01, 38.44it/s]
# Validation DataLoader 0:  72%|███████████▌    | 113/157 [00:02<00:01, 38.45it/s]
# Validation DataLoader 0:  73%|███████████▌    | 114/157 [00:02<00:01, 38.43it/s]
# Validation DataLoader 0:  73%|███████████▋    | 115/157 [00:02<00:01, 38.42it/s]
# Validation DataLoader 0:  74%|███████████▊    | 116/157 [00:03<00:01, 38.41it/s]
# Validation DataLoader 0:  75%|███████████▉    | 117/157 [00:03<00:01, 38.42it/s]
# Validation DataLoader 0:  75%|████████████    | 118/157 [00:03<00:01, 38.44it/s]
# Validation DataLoader 0:  76%|████████████▏   | 119/157 [00:03<00:00, 38.45it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:03<00:00, 38.44it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:03<00:00, 38.25it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:03<00:00, 38.25it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:03<00:00, 38.26it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:03<00:00, 38.26it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:03<00:00, 38.27it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:03<00:00, 38.26it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:03<00:00, 38.24it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:03<00:00, 38.23it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:03<00:00, 38.24it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:03<00:00, 38.24it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:03<00:00, 38.25it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:03<00:00, 38.17it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:03<00:00, 38.19it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:03<00:00, 38.18it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:03<00:00, 38.13it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:03<00:00, 38.11it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:03<00:00, 38.11it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:03<00:00, 38.12it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:03<00:00, 38.11it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:03<00:00, 37.93it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:03<00:00, 37.93it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:03<00:00, 37.96it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:03<00:00, 37.77it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:03<00:00, 37.70it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:03<00:00, 37.72it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:03<00:00, 37.71it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:03<00:00, 37.71it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:03<00:00, 37.70it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:03<00:00, 37.73it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:03<00:00, 37.74it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:04<00:00, 37.75it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:04<00:00, 37.74it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:04<00:00, 37.76it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:04<00:00, 37.75it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:04<00:00, 37.77it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:04<00:00, 37.76it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:04<00:00, 37.79it/s]
# Epoch 1: 100%|█| 782/782 [00:35<00:00, 21.96it/s, v_num=21, train_acc_step=0.625I0316 23:36:26.460790 139949971272768 rank_zero.py:63] `Trainer.fit` stopped: `max_epochs=2` reached.
# Epoch 1: 100%|█| 782/782 [00:35<00:00, 21.73it/s, v_num=21, train_acc_step=0.625
# INFO     Fine Tuning Complete
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_26/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# default_precision: int8
# Failed finding int8 cache!
# Failed finding int8 cache!
# Succeed saving int8 cache!
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_28/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/2025-03-16/version_29/model.json
# INFO     Measuring final TensorRT engine with warmup=20, test=500 ...
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/16/2025-23:44:02] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.73739    |
# |      Average Precision       |    0.73949    |
# |        Average Recall        |    0.74069    |
# |       Average F1 Score       |    0.73859    |
# |         Average Loss         |    0.7431     |
# |       Average Latency        |   2.2448 ms   |
# |   Average GPU Power Usage    |   15.399 W    |
# | Inference Energy Consumption | 0.0096021 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-16/tensorrt/version_8/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-16/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %%
RES_INT8_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/proj/resnet18_INT8_quant.toml"
RES_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {RES_INT8_BY_TYPE_TOML} --load {RES_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 02:21:21.056977 140494406755392 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 10, 'post_calibration_analysis': True, 'default': {'config': {'quantize': True, 'calibrators': ['percentile', 'mse', 'entropy'], 'percentiles': [99.0, 99.9, 99.99], 'precision': 'int8'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': True}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     Applying fake quantization to PyTorch model...
# op is placeholder
# placeholder not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is max_pool2d
# max_pool2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is conv2d
# node.op == call_module
# op is batch_norm2d
# batch_norm2d not in QUANTIZEABLE_OP
# op is add
# add not in QUANTIZEABLE_OP
# op is relu
# relu not in QUANTIZEABLE_OP
# op is adaptive_avg_pool2d
# adaptive_avg_pool2d not in QUANTIZEABLE_OP
# op is flatten
# flatten not in QUANTIZEABLE_OP
# op is linear
# node.op == call_module
# op is output
# output not in QUANTIZEABLE_OP
# INFO     Fake quantization applied to PyTorch model.
# INFO     Quantized graph histogram:
# INFO
# | Original type     | OP                  |   Total |   Changed |   Unchanged |
# |-------------------+---------------------+---------+-----------+-------------|
# | AdaptiveAvgPool2d | adaptive_avg_pool2d |       1 |         0 |           1 |
# | BatchNorm2d       | batch_norm2d        |      20 |         0 |          20 |
# | MaxPool2d         | max_pool2d          |       1 |         0 |           1 |
# | QuantConv2d       | conv2d              |      20 |         0 |          20 |
# | QuantLinear       | linear              |       1 |         0 |           1 |
# | ReLU              | relu                |      17 |         0 |          17 |
# | add               | add                 |       8 |         0 |           8 |
# | flatten           | flatten             |       1 |         0 |           1 |
# | output            | output              |       1 |         0 |           1 |
# | x                 | placeholder         |       1 |         0 |           1 |
# INFO     Starting calibration of the model in PyTorch...
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Disabling Quantization and Enabling Calibration
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.087997 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088167 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088266 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088348 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088433 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088517 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088604 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088695 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088779 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088858 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.088949 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089029 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089111 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089190 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089273 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089351 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089435 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089513 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089596 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089676 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089760 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089838 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089920 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.089999 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090083 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090162 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090245 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090325 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090409 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090490 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090573 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090651 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090734 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090822 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090906 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.090986 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091068 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091146 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091232 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091306 140494406755392 tensor_quantizer.py:174] Disable HistogramCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091391 140494406755392 tensor_quantizer.py:174] Disable MaxCalibrator
# INFO     Enabling Quantization and Disabling Calibration
# W0315 02:21:32.091465 140494406755392 tensor_quantizer.py:174] Disable MaxCalibrator
# W0315 02:21:32.091680 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W0315 02:21:32.091738 140494406755392 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6224 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.091941 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1400 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092101 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2234 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092239 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2111 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092375 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1065 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092510 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1980 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092655 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.8358 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092797 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1957 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.092946 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.1359 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093083 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1970 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093218 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.4627 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093343 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1583 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093477 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2610 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093605 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1586 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093736 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.4627 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.093876 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3493 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094006 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5872 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094131 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094259 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.2720 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094383 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1517 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094517 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.5370 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094642 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1277 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094769 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.6489 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.094891 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1132 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095019 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=4.5370 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095145 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2536 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095278 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4016 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095404 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095533 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.3014 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095656 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0944 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095781 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.2608 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.095990 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0710 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096137 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.5874 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096266 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0598 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096399 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=5.2608 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096525 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.1907 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096652 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=2.9013 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096777 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.096904 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.0223 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.097026 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0557 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:32.097127 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.6309 calibrator=MaxCalibrator scale=1.0 quant)
# W0315 02:21:32.097379 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.0...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72608    |
# |      Average Precision       |   0.71486    |
# |        Average Recall        |   0.71875    |
# |       Average F1 Score       |   0.71577    |
# |         Average Loss         |   0.81619    |
# |       Average Latency        |  29.604 ms   |
# |   Average GPU Power Usage    |   9.368 W    |
# | Inference Energy Consumption | 0.077035 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_10/model.json
# INFO     Post calibration analysis complete.
# W0315 02:21:38.361274 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=2.6384 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.362315 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.1815 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.362808 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.4700 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363099 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2904 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363385 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.2549 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363618 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2525 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.363879 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.1755 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364109 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2498 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364330 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.1552 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364542 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2537 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.364771 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.9494 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365005 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365243 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3049 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365498 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2041 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.365726 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=7.9494 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366071 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.4401 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366341 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=5.1995 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366575 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2007 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.366806 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=3.3943 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367028 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1949 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367249 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.7997 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367468 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1651 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.367899 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1052 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.368262 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1593 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.368669 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=6.7997 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369010 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.3283 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369326 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=6.6513 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369634 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1263 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.369944 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.1650 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.370243 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer3.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1284 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.370656 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4910 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.370944 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.1042 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.371239 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=7.3105 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.371532 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0840 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.371831 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=8.4910 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.372119 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.2463 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.372408 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.2235 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.372699 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0714 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.373008 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.4094 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.373312 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer4.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.0719 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:38.373595 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     fc._input_quantizer                     : TensorQuantizer(8bit fake per-tensor amax=19.6309 calibrator=MaxCalibrator scale=1.0 quant)
# W0315 02:21:38.373790 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([10, 1]).
# INFO     fc._weight_quantizer                    : TensorQuantizer(8bit fake axis=0 amax=[0.0832, 0.1520](10) calibrator=MaxCalibrator scale=1.0 quant)
# INFO     Performing post calibration analysis for calibrator percentile_99.9...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# | Average Validation Accuracy  |   0.72868    |
# |      Average Precision       |   0.71952    |
# |        Average Recall        |   0.72268    |
# |       Average F1 Score       |    0.7203    |
# |         Average Loss         |   0.80705    |
# |       Average Latency        |  27.485 ms   |
# |   Average GPU Power Usage    |   10.18 W    |
# | Inference Energy Consumption | 0.077725 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_11/model.json
# INFO     Post calibration analysis complete.
# W0315 02:21:44.078727 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._input_quantizer                  : TensorQuantizer(8bit fake per-tensor amax=3.0570 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.079337 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     conv1._weight_quantizer                 : TensorQuantizer(8bit fake per-tensor amax=0.2071 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.079652 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=8.8774 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.079928 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.3663 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080175 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.4204 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080457 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2896 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080696 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=9.6484 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.080967 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2951 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081194 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.2232 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081415 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer1.1.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2948 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081642 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=10.5421 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.081875 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv1._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2492 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082105 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._input_quantizer         : TensorQuantizer(8bit fake per-tensor amax=4.3595 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082331 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.conv2._weight_quantizer        : TensorQuantizer(8bit fake per-tensor amax=0.2424 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082558 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._input_quantizer  : TensorQuantizer(8bit fake per-tensor amax=10.5421 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.082784 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# INFO     layer2.0.downsample.0._weight_quantizer : TensorQuantizer(8bit fake per-tensor amax=0.5430 calibrator=HistogramCalibrator scale=1.0 quant)
# W0315 02:21:44.083009 140494406755392 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# ...
# Validation:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/157 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|                  | 1/157 [00:00<00:03, 41.78it/s]
# Validation DataLoader 0:   1%|▏                 | 2/157 [00:00<00:03, 45.54it/s]
# Validation DataLoader 0:   2%|▎                 | 3/157 [00:00<00:03, 47.20it/s]
# Validation DataLoader 0:   3%|▍                 | 4/157 [00:00<00:03, 44.01it/s]
# Validation DataLoader 0:   3%|▌                 | 5/157 [00:00<00:03, 44.88it/s]
# Validation DataLoader 0:   4%|▋                 | 6/157 [00:00<00:03, 45.40it/s]
# Validation DataLoader 0:   4%|▊                 | 7/157 [00:00<00:03, 43.46it/s]
# Validation DataLoader 0:   5%|▉                 | 8/157 [00:00<00:03, 44.17it/s]
# Validation DataLoader 0:   6%|█                 | 9/157 [00:00<00:03, 44.15it/s]
# Validation DataLoader 0:   6%|█                | 10/157 [00:00<00:03, 43.40it/s]
# Validation DataLoader 0:   7%|█▏               | 11/157 [00:00<00:03, 43.34it/s]
# Validation DataLoader 0:   8%|█▎               | 12/157 [00:00<00:03, 43.85it/s]
# Validation DataLoader 0:   8%|█▍               | 13/157 [00:00<00:03, 44.09it/s]
# Validation DataLoader 0:   9%|█▌               | 14/157 [00:00<00:03, 44.18it/s]
# Validation DataLoader 0:  10%|█▌               | 15/157 [00:00<00:03, 43.69it/s]
# Validation DataLoader 0:  10%|█▋               | 16/157 [00:00<00:03, 43.76it/s]
# Validation DataLoader 0:  11%|█▊               | 17/157 [00:00<00:03, 43.80it/s]
# Validation DataLoader 0:  11%|█▉               | 18/157 [00:00<00:03, 43.52it/s]
# Validation DataLoader 0:  12%|██               | 19/157 [00:00<00:03, 43.73it/s]
# Validation DataLoader 0:  13%|██▏              | 20/157 [00:00<00:03, 43.54it/s]
# Validation DataLoader 0:  13%|██▎              | 21/157 [00:00<00:03, 43.83it/s]
# Validation DataLoader 0:  14%|██▍              | 22/157 [00:00<00:03, 43.50it/s]
# Validation DataLoader 0:  15%|██▍              | 23/157 [00:00<00:03, 43.71it/s]
# Validation DataLoader 0:  15%|██▌              | 24/157 [00:00<00:03, 44.12it/s]
# Validation DataLoader 0:  16%|██▋              | 25/157 [00:00<00:03, 43.95it/s]
# Validation DataLoader 0:  17%|██▊              | 26/157 [00:00<00:02, 44.04it/s]
# Validation DataLoader 0:  17%|██▉              | 27/157 [00:00<00:02, 44.17it/s]
# Validation DataLoader 0:  18%|███              | 28/157 [00:00<00:02, 44.19it/s]
# Validation DataLoader 0:  18%|███▏             | 29/157 [00:00<00:02, 43.33it/s]
# Validation DataLoader 0:  19%|███▏             | 30/157 [00:00<00:02, 43.30it/s]
# Validation DataLoader 0:  20%|███▎             | 31/157 [00:00<00:02, 42.61it/s]
# Validation DataLoader 0:  20%|███▍             | 32/157 [00:00<00:02, 42.09it/s]
# Validation DataLoader 0:  21%|███▌             | 33/157 [00:00<00:02, 41.85it/s]
# Validation DataLoader 0:  22%|███▋             | 34/157 [00:00<00:02, 41.93it/s]
# Validation DataLoader 0:  22%|███▊             | 35/157 [00:00<00:02, 42.01it/s]
# Validation DataLoader 0:  23%|███▉             | 36/157 [00:00<00:02, 42.07it/s]
# Validation DataLoader 0:  24%|████             | 37/157 [00:00<00:02, 42.15it/s]
# Validation DataLoader 0:  24%|████             | 38/157 [00:00<00:02, 42.29it/s]
# Validation DataLoader 0:  25%|████▏            | 39/157 [00:00<00:02, 42.13it/s]
# Validation DataLoader 0:  25%|████▎            | 40/157 [00:00<00:02, 42.28it/s]
# Validation DataLoader 0:  26%|████▍            | 41/157 [00:00<00:02, 42.32it/s]
# Validation DataLoader 0:  27%|████▌            | 42/157 [00:00<00:02, 42.35it/s]
# Validation DataLoader 0:  27%|████▋            | 43/157 [00:01<00:02, 41.86it/s]
# Validation DataLoader 0:  28%|████▊            | 44/157 [00:01<00:02, 41.87it/s]
# Validation DataLoader 0:  29%|████▊            | 45/157 [00:01<00:02, 41.82it/s]
# Validation DataLoader 0:  29%|████▉            | 46/157 [00:01<00:02, 41.82it/s]
# Validation DataLoader 0:  30%|█████            | 47/157 [00:01<00:02, 41.79it/s]
# Validation DataLoader 0:  31%|█████▏           | 48/157 [00:01<00:02, 41.87it/s]
# Validation DataLoader 0:  31%|█████▎           | 49/157 [00:01<00:02, 41.61it/s]
# Validation DataLoader 0:  32%|█████▍           | 50/157 [00:01<00:02, 41.67it/s]
# Validation DataLoader 0:  32%|█████▌           | 51/157 [00:01<00:02, 41.15it/s]
# Validation DataLoader 0:  33%|█████▋           | 52/157 [00:01<00:02, 41.14it/s]
# Validation DataLoader 0:  34%|█████▋           | 53/157 [00:01<00:02, 41.18it/s]
# Validation DataLoader 0:  34%|█████▊           | 54/157 [00:01<00:02, 41.17it/s]
# Validation DataLoader 0:  35%|█████▉           | 55/157 [00:01<00:02, 41.23it/s]
# Validation DataLoader 0:  36%|██████           | 56/157 [00:01<00:02, 41.32it/s]
# Validation DataLoader 0:  36%|██████▏          | 57/157 [00:01<00:02, 41.32it/s]
# Validation DataLoader 0:  37%|██████▎          | 58/157 [00:01<00:02, 41.35it/s]
# Validation DataLoader 0:  38%|██████▍          | 59/157 [00:01<00:02, 41.23it/s]
# Validation DataLoader 0:  38%|██████▍          | 60/157 [00:01<00:02, 41.30it/s]
# Validation DataLoader 0:  39%|██████▌          | 61/157 [00:01<00:02, 41.01it/s]
# Validation DataLoader 0:  39%|██████▋          | 62/157 [00:01<00:02, 40.92it/s]
# Validation DataLoader 0:  40%|██████▊          | 63/157 [00:01<00:02, 40.93it/s]
# Validation DataLoader 0:  41%|██████▉          | 64/157 [00:01<00:02, 40.97it/s]
# Validation DataLoader 0:  41%|███████          | 65/157 [00:01<00:02, 40.93it/s]
# Validation DataLoader 0:  42%|███████▏         | 66/157 [00:01<00:02, 40.73it/s]
# Validation DataLoader 0:  43%|███████▎         | 67/157 [00:01<00:02, 40.75it/s]
# Validation DataLoader 0:  43%|███████▎         | 68/157 [00:01<00:02, 40.78it/s]
# Validation DataLoader 0:  44%|███████▍         | 69/157 [00:01<00:02, 40.84it/s]
# Validation DataLoader 0:  45%|███████▌         | 70/157 [00:01<00:02, 40.91it/s]
# Validation DataLoader 0:  45%|███████▋         | 71/157 [00:01<00:02, 40.87it/s]
# Validation DataLoader 0:  46%|███████▊         | 72/157 [00:01<00:02, 40.90it/s]
# Validation DataLoader 0:  46%|███████▉         | 73/157 [00:01<00:02, 40.79it/s]
# Validation DataLoader 0:  47%|████████         | 74/157 [00:01<00:02, 40.80it/s]
# Validation DataLoader 0:  48%|████████         | 75/157 [00:01<00:02, 40.77it/s]
# Validation DataLoader 0:  48%|████████▏        | 76/157 [00:01<00:01, 40.67it/s]
# Validation DataLoader 0:  49%|████████▎        | 77/157 [00:01<00:01, 40.59it/s]
# Validation DataLoader 0:  50%|████████▍        | 78/157 [00:01<00:01, 40.46it/s]
# Validation DataLoader 0:  50%|████████▌        | 79/157 [00:01<00:01, 40.07it/s]
# Validation DataLoader 0:  51%|████████▋        | 80/157 [00:02<00:01, 39.94it/s]
# Validation DataLoader 0:  52%|████████▊        | 81/157 [00:02<00:01, 39.89it/s]
# Validation DataLoader 0:  52%|████████▉        | 82/157 [00:02<00:01, 39.68it/s]
# Validation DataLoader 0:  53%|████████▉        | 83/157 [00:02<00:01, 39.60it/s]
# Validation DataLoader 0:  54%|█████████        | 84/157 [00:02<00:01, 39.51it/s]
# Validation DataLoader 0:  54%|█████████▏       | 85/157 [00:02<00:01, 39.51it/s]
# Validation DataLoader 0:  55%|█████████▎       | 86/157 [00:02<00:01, 39.43it/s]
# Validation DataLoader 0:  55%|█████████▍       | 87/157 [00:02<00:01, 39.45it/s]
# Validation DataLoader 0:  56%|█████████▌       | 88/157 [00:02<00:01, 39.45it/s]
# Validation DataLoader 0:  57%|█████████▋       | 89/157 [00:02<00:01, 39.48it/s]
# Validation DataLoader 0:  57%|█████████▋       | 90/157 [00:02<00:01, 39.40it/s]
# Validation DataLoader 0:  58%|█████████▊       | 91/157 [00:02<00:01, 39.40it/s]
# Validation DataLoader 0:  59%|█████████▉       | 92/157 [00:02<00:01, 39.38it/s]
# Validation DataLoader 0:  59%|██████████       | 93/157 [00:02<00:01, 39.35it/s]
# Validation DataLoader 0:  60%|██████████▏      | 94/157 [00:02<00:01, 39.27it/s]
# Validation DataLoader 0:  61%|██████████▎      | 95/157 [00:02<00:01, 39.31it/s]
# Validation DataLoader 0:  61%|██████████▍      | 96/157 [00:02<00:01, 39.34it/s]
# Validation DataLoader 0:  62%|██████████▌      | 97/157 [00:02<00:01, 39.32it/s]
# Validation DataLoader 0:  62%|██████████▌      | 98/157 [00:02<00:01, 39.28it/s]
# Validation DataLoader 0:  63%|██████████▋      | 99/157 [00:02<00:01, 39.09it/s]
# Validation DataLoader 0:  64%|██████████▏     | 100/157 [00:02<00:01, 39.12it/s]
# Validation DataLoader 0:  64%|██████████▎     | 101/157 [00:02<00:01, 39.15it/s]
# Validation DataLoader 0:  65%|██████████▍     | 102/157 [00:02<00:01, 39.13it/s]
# Validation DataLoader 0:  66%|██████████▍     | 103/157 [00:02<00:01, 39.03it/s]
# Validation DataLoader 0:  66%|██████████▌     | 104/157 [00:02<00:01, 39.05it/s]
# Validation DataLoader 0:  67%|██████████▋     | 105/157 [00:02<00:01, 39.03it/s]
# Validation DataLoader 0:  68%|██████████▊     | 106/157 [00:02<00:01, 38.95it/s]
# Validation DataLoader 0:  68%|██████████▉     | 107/157 [00:02<00:01, 38.69it/s]
# Validation DataLoader 0:  69%|███████████     | 108/157 [00:02<00:01, 38.70it/s]
# Validation DataLoader 0:  69%|███████████     | 109/157 [00:02<00:01, 38.70it/s]
# Validation DataLoader 0:  70%|███████████▏    | 110/157 [00:02<00:01, 38.64it/s]
# Validation DataLoader 0:  71%|███████████▎    | 111/157 [00:02<00:01, 38.65it/s]
# Validation DataLoader 0:  71%|███████████▍    | 112/157 [00:02<00:01, 38.65it/s]
# Validation DataLoader 0:  72%|███████████▌    | 113/157 [00:02<00:01, 38.63it/s]
# Validation DataLoader 0:  73%|███████████▌    | 114/157 [00:02<00:01, 38.57it/s]
# Validation DataLoader 0:  73%|███████████▋    | 115/157 [00:02<00:01, 38.46it/s]
# Validation DataLoader 0:  74%|███████████▊    | 116/157 [00:03<00:01, 38.47it/s]
# Validation DataLoader 0:  75%|███████████▉    | 117/157 [00:03<00:01, 38.48it/s]
# Validation DataLoader 0:  75%|████████████    | 118/157 [00:03<00:01, 38.49it/s]
# Validation DataLoader 0:  76%|████████████▏   | 119/157 [00:03<00:00, 38.32it/s]
# Validation DataLoader 0:  76%|████████████▏   | 120/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  77%|████████████▎   | 121/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  78%|████████████▍   | 122/157 [00:03<00:00, 38.14it/s]
# Validation DataLoader 0:  78%|████████████▌   | 123/157 [00:03<00:00, 38.20it/s]
# Validation DataLoader 0:  79%|████████████▋   | 124/157 [00:03<00:00, 38.22it/s]
# Validation DataLoader 0:  80%|████████████▋   | 125/157 [00:03<00:00, 38.19it/s]
# Validation DataLoader 0:  80%|████████████▊   | 126/157 [00:03<00:00, 38.19it/s]
# Validation DataLoader 0:  81%|████████████▉   | 127/157 [00:03<00:00, 38.22it/s]
# Validation DataLoader 0:  82%|█████████████   | 128/157 [00:03<00:00, 38.20it/s]
# Validation DataLoader 0:  82%|█████████████▏  | 129/157 [00:03<00:00, 38.23it/s]
# Validation DataLoader 0:  83%|█████████████▏  | 130/157 [00:03<00:00, 38.25it/s]
# Validation DataLoader 0:  83%|█████████████▎  | 131/157 [00:03<00:00, 38.28it/s]
# Validation DataLoader 0:  84%|█████████████▍  | 132/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  85%|█████████████▌  | 133/157 [00:03<00:00, 38.30it/s]
# Validation DataLoader 0:  85%|█████████████▋  | 134/157 [00:03<00:00, 38.33it/s]
# Validation DataLoader 0:  86%|█████████████▊  | 135/157 [00:03<00:00, 38.31it/s]
# Validation DataLoader 0:  87%|█████████████▊  | 136/157 [00:03<00:00, 38.36it/s]
# Validation DataLoader 0:  87%|█████████████▉  | 137/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  88%|██████████████  | 138/157 [00:03<00:00, 38.42it/s]
# Validation DataLoader 0:  89%|██████████████▏ | 139/157 [00:03<00:00, 38.39it/s]
# Validation DataLoader 0:  89%|██████████████▎ | 140/157 [00:03<00:00, 38.39it/s]
# Validation DataLoader 0:  90%|██████████████▎ | 141/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  90%|██████████████▍ | 142/157 [00:03<00:00, 38.36it/s]
# Validation DataLoader 0:  91%|██████████████▌ | 143/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  92%|██████████████▋ | 144/157 [00:03<00:00, 38.41it/s]
# Validation DataLoader 0:  92%|██████████████▊ | 145/157 [00:03<00:00, 38.41it/s]
# Validation DataLoader 0:  93%|██████████████▉ | 146/157 [00:03<00:00, 38.40it/s]
# Validation DataLoader 0:  94%|██████████████▉ | 147/157 [00:03<00:00, 38.37it/s]
# Validation DataLoader 0:  94%|███████████████ | 148/157 [00:03<00:00, 38.33it/s]
# Validation DataLoader 0:  95%|███████████████▏| 149/157 [00:03<00:00, 38.33it/s]
# Validation DataLoader 0:  96%|███████████████▎| 150/157 [00:03<00:00, 38.34it/s]
# Validation DataLoader 0:  96%|███████████████▍| 151/157 [00:03<00:00, 38.38it/s]
# Validation DataLoader 0:  97%|███████████████▍| 152/157 [00:03<00:00, 38.37it/s]
# Validation DataLoader 0:  97%|███████████████▌| 153/157 [00:03<00:00, 38.39it/s]
# Validation DataLoader 0:  98%|███████████████▋| 154/157 [00:04<00:00, 38.39it/s]
# Validation DataLoader 0:  99%|███████████████▊| 155/157 [00:04<00:00, 38.43it/s]
# Validation DataLoader 0:  99%|███████████████▉| 156/157 [00:04<00:00, 38.43it/s]
# Validation DataLoader 0: 100%|████████████████| 157/157 [00:04<00:00, 38.34it/s]
# Epoch 1: 100%|█| 782/782 [00:35<00:00, 22.01it/s, v_num=13, train_acc_step=0.125I0315 02:24:27.561993 140494406755392 rank_zero.py:63] `Trainer.fit` stopped: `max_epochs=2` reached.
# Epoch 1: 100%|█| 782/782 [00:35<00:00, 21.88it/s, v_num=13, train_acc_step=0.125
# INFO     Fine Tuning Complete
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_17/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_18/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_19/model.json
# INFO     Running minimal runtime analysis on original graph (just 1 batch) ...
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+-------------+
# |      Metric (Per Batch)      |    Value    |
# +------------------------------+-------------+
# |    Average Test Accuracy     |   0.68146   |
# |      Average Precision       |   0.7399    |
# |        Average Recall        |   0.70312   |
# |       Average F1 Score       |   0.70984   |
# |         Average Loss         |    0.895    |
# |       Average Latency        |  48.939 ms  |
# |   Average GPU Power Usage    |  8.1492 W   |
# | Inference Energy Consumption | 0.11078 mWh |
# +------------------------------+-------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_15/model.json
# INFO     Measuring final TensorRT engine with warmup=20, test=500 ...
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-02:27:22] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.73975    |
# |      Average Precision       |   0.74038    |
# |        Average Recall        |   0.74242    |
# |       Average F1 Score       |   0.74044    |
# |         Average Loss         |   0.73944    |
# |       Average Latency        |   3.601 ms   |
# |   Average GPU Power Usage    |   13.729 W   |
# | Inference Energy Consumption | 0.013733 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_5/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %% [markdown]
# ### FP16 Conversion with TensorRT
#
# #### Overview
# This section describes the process of converting a model to **FP16 precision** using TensorRT. Unlike **INT8 quantization**, **FP16 does not require calibration, fake quantization, or fine-tuning**. The conversion process is simpler and primarily focuses on **speeding up inference while maintaining high precision**.
#
# ### Code Execution Flow
#
# 1. **Apply TensorRT FP16 Pass**
#    - **No Fake Quantization**: Since FP16 does not require quantization-aware training, the `quantize` option is set to `false`.
#    - **No Calibration**: Unlike INT8, FP16 does not need calibration data, so `num_calibration_batches` is set to `0`.
#    - **No Fine-Tuning**: Additional training is unnecessary in FP16 mode.
#
# 2. **Generate the TensorRT Engine**
#    - Calls `tensorrt_engine_interface_pass` to convert the model to a **TensorRT FP16 engine**.
#
# 3. **Benchmarking & Performance Analysis**
#    - Runs inference tests with warm-up and batch evaluation to measure efficiency.

# %%
RES_FP16_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/proj/resnet18_FP16_quant.toml"
RES_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {RES_FP16_BY_TYPE_TOML} --load {RES_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 01:36:29.907291 139755539158080 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 0, 'post_calibration_analysis': False, 'default': {'config': {'quantize': False, 'precision': 'fp16'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': False}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     precision=fp16, skipping int8 calibration/fine-tune...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_7/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_8/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_9/model.json
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72852    |
# |      Average Precision       |   0.71886    |
# |        Average Recall        |   0.72227    |
# |       Average F1 Score       |   0.71961    |
# |         Average Loss         |   0.80975    |
# |       Average Latency        |  8.0633 ms   |
# |   Average GPU Power Usage    |   13.007 W   |
# | Inference Energy Consumption | 0.029134 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_7/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-01:36:52] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.74178    |
# |      Average Precision       |    0.7423     |
# |        Average Recall        |    0.74514    |
# |       Average F1 Score       |    0.74268    |
# |         Average Loss         |    0.73414    |
# |       Average Latency        |   1.0096 ms   |
# |   Average GPU Power Usage    |   9.6732 W    |
# | Inference Energy Consumption | 0.0027127 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_2/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %% [markdown]
# ### FP32 Conversion with TensorRT
#
# The process for converting a model to **FP32 precision** using TensorRT is quite similar to the **FP16 conversion**, but with even fewer modifications. Since FP32 is the default precision for deep learning models, the main goal here is to **leverage TensorRT optimizations** without changing the numerical format.

# %%
RES_FP32_BY_TYPE_TOML = "/workspace/ADLS_Proj/docs/tutorials/proj/resnet18_FP32_quant.toml"
RES_CHECKPOINT_PATH = "/workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt"
# !python ch transform --config {RES_FP32_BY_TYPE_TOML} --load {RES_CHECKPOINT_PATH} --load-type pl
# Out:
# /srcPkgs/miniconda3/lib/python3.11/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# INFO: Seed set to 0
# WARNING: Logging before flag parsing goes to stderr.
# I0315 01:43:15.535419 140335826768960 seed.py:57] Seed set to 0
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | Name                    |         Default          | Config. File |     Manual Override      |        Effective         |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# | task                    |      classification      |     cls      |                          |           cls            |
# | load_name               |           None           |              | /workspace/ADLS_Proj/mas | /workspace/ADLS_Proj/mas |
# |                         |                          |              | e_output/resnet18_cls_ci | e_output/resnet18_cls_ci |
# |                         |                          |              | far10_2025-03-08/softwar | far10_2025-03-08/softwar |
# |                         |                          |              | e/training_ckpts/best.ck | e/training_ckpts/best.ck |
# |                         |                          |              |            pt            |            pt            |
# | load_type               |            mz            |              |            pl            |            pl            |
# | batch_size              |           128            |      64      |                          |            64            |
# | to_debug                |          False           |              |                          |          False           |
# | log_level               |           info           |              |                          |           info           |
# | report_to               |       tensorboard        |              |                          |       tensorboard        |
# | seed                    |            0             |              |                          |            0             |
# | quant_config            |           None           |              |                          |           None           |
# | training_optimizer      |           adam           |              |                          |           adam           |
# | trainer_precision       |         16-mixed         |              |                          |         16-mixed         |
# | learning_rate           |          1e-05           |    0.001     |                          |          0.001           |
# | weight_decay            |            0             |              |                          |            0             |
# | max_epochs              |            20            |      10      |                          |            10            |
# | max_steps               |            -1            |              |                          |            -1            |
# | accumulate_grad_batches |            1             |              |                          |            1             |
# | log_every_n_steps       |            50            |              |                          |            50            |
# | num_workers             |            20            |              |                          |            20            |
# | num_devices             |            1             |              |                          |            1             |
# | num_nodes               |            1             |              |                          |            1             |
# | accelerator             |           auto           |     gpu      |                          |           gpu            |
# | strategy                |           auto           |              |                          |           auto           |
# | is_to_auto_requeue      |          False           |              |                          |          False           |
# | github_ci               |          False           |              |                          |          False           |
# | disable_dataset_cache   |          False           |              |                          |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                          |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                          |           100            |
# | is_pretrained           |          False           |              |                          |          False           |
# | max_token_len           |           512            |              |                          |           512            |
# | project_dir             | /workspace/ADLS_Proj/mas |              |                          | /workspace/ADLS_Proj/mas |
# |                         |         e_output         |              |                          |         e_output         |
# | project                 |           None           |              |                          |           None           |
# | model                   |           None           |   resnet18   |                          |         resnet18         |
# | dataset                 |           None           |   cifar10    |                          |         cifar10          |
# | t_max                   |            20            |              |                          |            20            |
# | eta_min                 |          1e-06           |              |                          |          1e-06           |
# +-------------------------+--------------------------+--------------+--------------------------+--------------------------+
# INFO     Initialising model 'resnet18'...
# self.args.model is resnet18
# model_info is MaseModelInfo(name='resnet', model_source=<ModelSource.TORCHVISION: 'torchvision'>, task_type=<ModelTaskType.VISION: 'vision'>, image_classification=True, physical_data_point_classification=False, sequence_classification=False, seq2seqLM=False, causal_LM=False, is_quantized=False, is_lora=False, is_sparse=False, is_fx_traceable=True)
# INFO     Initialising dataset 'cifar10'...
# INFO     Project will be created at /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15
# INFO     Transforming model 'resnet18'...
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# {'model': 'resnet18', 'dataset': 'cifar10', 'max_epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'accelerator': 'gpu', 'task': 'cls', 'transform': {'style': 'graph'}, 'passes': {'tensorrt': {'by': 'type', 'num_calibration_batches': 0, 'post_calibration_analysis': False, 'default': {'config': {'quantize': False, 'precision': 'fp32'}, 'input': {'calibrator': 'histogram', 'quantize_axis': False}, 'weight': {'calibrator': 'histogram', 'quantize_axis': False}}, 'fine_tune': {'fine_tune': False}, 'runtime_analysis': {'num_batches': 500, 'num_GPU_warmup_batches': 5, 'test': True}}}}
# INFO     Loaded pytorch lightning checkpoint from /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-08/software/training_ckpts/best.ckpt
# using safe deepcopy
# INFO     precision=fp32, skipping int8 calibration/fine-tune...
# INFO     Converting PyTorch model to ONNX...
# INFO     ONNX Conversion Complete. Stored ONNX model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_13/model.onnx
# INFO     Converting PyTorch model to TensorRT...
# INFO     TensorRT Conversion Complete. Stored trt model to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_14/model.trt
# INFO     TensorRT Model Summary Exported to /workspace/ADLS_Proj/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/2025-03-15/version_15/model.json
# INFO     Starting transformation analysis on resnet18
# INFO
# Results resnet18:
# +------------------------------+--------------+
# |      Metric (Per Batch)      |    Value     |
# +------------------------------+--------------+
# |    Average Test Accuracy     |   0.72852    |
# |      Average Precision       |   0.71886    |
# |        Average Recall        |   0.72227    |
# |       Average F1 Score       |   0.71961    |
# |         Average Loss         |   0.80975    |
# |       Average Latency        |  8.3068 ms   |
# |   Average GPU Power Usage    |   17.661 W   |
# | Inference Energy Consumption | 0.040752 mWh |
# +------------------------------+--------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/mase_graph/version_9/model.json
# INFO     Starting transformation analysis on resnet18-trt_quantized
# [03/15/2025-01:43:32] [TRT] [W] Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO
# Results resnet18-trt_quantized:
# +------------------------------+---------------+
# |      Metric (Per Batch)      |     Value     |
# +------------------------------+---------------+
# |    Average Test Accuracy     |    0.74162    |
# |      Average Precision       |    0.74235    |
# |        Average Recall        |    0.74514    |
# |       Average F1 Score       |    0.7427     |
# |         Average Loss         |    0.73414    |
# |       Average Latency        |   2.706 ms    |
# |   Average GPU Power Usage    |   11.678 W    |
# | Inference Energy Consumption | 0.0087779 mWh |
# +------------------------------+---------------+
# INFO     Runtime analysis results saved to /workspace/mase_output/tensorrt/quantization/resnet18_cls_cifar10_2025-03-15/tensorrt/version_4/model.json
# INFO     Saved mase graph to /workspace/ADLS_Proj/mase_output/resnet18_cls_cifar10_2025-03-15/software/transform/transformed_ckpt
# INFO     Transformation is completed

# %% [markdown]
# ### Results on RTX 4060 with ResNet18 and CIFAR-10
#
# The following results were obtained while running **ResNet18 on CIFAR-10** using **TensorRT** on an **RTX 4060 GPU**.
#
# #### **Accuracy Comparison**
# | Model Version   | Accuracy |
# |----------------|----------|
# | **Original (FP32)**  | **0.73**  |
# | **After Quantization**  | **0.74**  |
#
# - The slight accuracy **increase** after quantization is attributed to **QAT**.
#
# #### **Latency Reduction**
# | Precision Mode | Initial Latency | Optimized Latency |
# |---------------|----------------|------------------|
# | **FP32**      | 8.3ms            | **2.7ms**        |
# | **FP16**      | 8.1ms            | **1.0ms**        |
# | **INT8**      | 9.1ms            | **2.2ms**        |
#
# - **FP32 to FP16** significantly reduces latency, bringing it down to **1.0ms**.
# - **INT8 inference** achieves **4.4ms latency**, but there is an issue related to **deepcopy** during the conversion process.
#   - If **runtime analysis is not performed on the original model before fake quantization**, the process **consumes significantly more time**, which is unexpected.

# %% [markdown]
# ### Results on RTX 4060 with ResNet50 and CIFAR-10
#
# The following results were obtained while running **ResNet50 on CIFAR-10** using **TensorRT** on an **RTX 4060 GPU**.
#
# #### **Accuracy Comparison**
# | Model Version       | Accuracy |
# |--------------------|----------|
# | **Original (FP32)** | **0.52**  |
# | **After Quantization** | **0.52**  |
#
# - The accuracy remains **unchanged** after quantization, indicating a stable conversion process.
#
# #### **Latency Reduction**
# | Precision Mode | Initial Latency | Optimized Latency |
# |---------------|----------------|------------------|
# | **FP32**      | **30.1ms**      | **3.1ms**        |
# | **FP16**      | **23.8ms**      | **1.5ms**        |
# | **INT8**      | **36.2ms**      | **6.4ms**       |
#
# - **FP32 to FP16** brings a **significant latency reduction**, decreasing to **1.5ms**.
# - **INT8 inference** reduces latency to **6.4ms**, but compared to FP16/32, it's still larger, don't know if it's the problem of resnet stucture.

# %% [markdown]
# ### Results on RTX 4060 with VGG7 and CIFAR-10
#
# The following results were obtained while running **VGG7 on CIFAR-10** using **TensorRT** on an **RTX 4060 GPU**.
#
# #### **Accuracy Comparison**
# | Model Version       | Accuracy |
# |--------------------|----------|
# | **Original (FP32)** | **0.78**  |
# | **After Quantization (INT8)** | **0.79**  |
#
# - The accuracy slightly **increases** after quantization, likely due to **QAT optimizations**.
#
# #### **Latency Reduction**
# | Precision Mode | Initial Latency | Optimized Latency |
# |---------------|----------------|------------------|
# | **FP32**      | **11.72ms**     | **7.04ms**       |
# | **FP16**      | **11.72ms**     | **2.52ms**       |
# | **INT8**      | **10.04ms**     | **1.30ms**      |
#
# - **FP32 to FP16** results in a **notable latency drop** to **2.52ms**.
# - **INT8 inference** achieves a **latency of 1.3ms**, faster than FP16/FP32, much better than that in Resnet.
